# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.2: Forward Feature Selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 5. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 5.1 Load Wine Data & Define Predictor and Target

# %%
## Load the wine quality dataset

# Load the wine dataset from csv
wine = pd.read_csv('winequality_merged.csv')

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']
# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
## Create training and testing subsets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### 5.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
## Flag intermediate output

show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = ['volatile acidity']
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
# create a model object to hold the modelling parameters
model = LinearRegression() # create a model for Linear Regression
# get the number of cases in the test data
n = X_test.shape[0]

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))

        # fit the model with the Training data
        fit = model.fit(X_train[included],y_train) # fit a model; consider which predictors should be included
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X_train[included],y_train) # calculate the score
        # number of predictors in this model
        k = len(included) + 1
        # calculate the adjusted R^2
        adjusted_r2 = 1 - (1-r2)*((len(y)-1)/(len(y)-k)) # calculate the Adjusted R^2

        if show_steps:
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = free sulfur dioxide, chlorides, density, red_wine, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) Trying free sulfur dioxide...
# (Step) - Features = volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.075; Best = 0.000
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.075; Adjusted R^2 = 0.075
# (Step) Trying chlorides...
# (Step) - Features = volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying density...
# (Step) - Features = volatile acidity, density
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying red_wine...
# (Step) - Features = volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying total sulfur dioxide...
# (Step) - Features = volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying pH...
# (Step) - Features = volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying citric acid...
# (Step) - Features = volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, alcohol
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.075; Best = 0.075
# Added feature free sulfur dioxide with R^2 = 0.075 and adjusted R^2 = 0.075
#
# (Step) Excluded = chlorides, density, red_wine, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) Trying chlorides...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.076; Best = 0.075
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.076; Adjusted R^2 = 0.076
# (Step) Trying density...
# (Step) - Features = volatile acidity, free sulfur dioxide, density
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying red_wine...
# (Step) - Features = volatile acidity, free sulfur dioxide, red_wine
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying total sulfur dioxide...
# (Step) - Features = volatile acidity, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying pH...
# (Step) - Features = volatile acidity, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying citric acid...
# (Step) - Features = volatile acidity, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, alcohol
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, residual sugar
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, sulphates
# (Step) - Adjusted R^2: This = 0.076; Best = 0.076
# Added feature chlorides with R^2 = 0.076 and adjusted R^2 = 0.076
#
# (Step) Excluded = red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) Trying red_wine...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine
# (Step) - Adjusted R^2: This = 0.088; Best = 0.076
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.088; Adjusted R^2 = 0.088
# (Step) Trying density...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, density
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# (Step) Trying total sulfur dioxide...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# (Step) Trying pH...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, pH
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# (Step) Trying citric acid...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, citric acid
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, fixed acidity
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, alcohol
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, residual sugar
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, sulphates
# (Step) - Adjusted R^2: This = 0.088; Best = 0.088
# Added feature red_wine with R^2 = 0.088 and adjusted R^2 = 0.088
#
# (Step) Excluded = density, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) Trying density...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density
# (Step) - Adjusted R^2: This = 0.101; Best = 0.088
# (Step) - New Best!   : Feature = density; R^2 = 0.102; Adjusted R^2 = 0.101
# (Step) Trying total sulfur dioxide...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.101; Best = 0.101
# (Step) Trying pH...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, pH
# (Step) - Adjusted R^2: This = 0.101; Best = 0.101
# (Step) Trying citric acid...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.101; Best = 0.101
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.101; Best = 0.101
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, alcohol
# (Step) - Adjusted R^2: This = 0.101; Best = 0.101
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, residual sugar
# (Step) - Adjusted R^2: This = 0.101; Best = 0.101
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, sulphates
# (Step) - Adjusted R^2: This = 0.101; Best = 0.101
# Added feature density with R^2 = 0.102 and adjusted R^2 = 0.101
#
# (Step) Excluded = total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) Trying total sulfur dioxide...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.162; Best = 0.101
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.163; Adjusted R^2 = 0.162
# (Step) Trying pH...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, pH
# (Step) - Adjusted R^2: This = 0.162; Best = 0.162
# (Step) Trying citric acid...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, citric acid
# (Step) - Adjusted R^2: This = 0.162; Best = 0.162
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.162; Best = 0.162
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, alcohol
# (Step) - Adjusted R^2: This = 0.162; Best = 0.162
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, residual sugar
# (Step) - Adjusted R^2: This = 0.162; Best = 0.162
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, sulphates
# (Step) - Adjusted R^2: This = 0.162; Best = 0.162
# Added feature total sulfur dioxide with R^2 = 0.163 and adjusted R^2 = 0.162
#
# (Step) Excluded = pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) Trying pH...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.168; Best = 0.162
# (Step) - New Best!   : Feature = pH; R^2 = 0.168; Adjusted R^2 = 0.168
# (Step) Trying citric acid...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, alcohol
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, residual sugar
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, sulphates
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# Added feature pH   with R^2 = 0.168 and adjusted R^2 = 0.168
#
# (Step) Excluded = citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) Trying citric acid...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.169; Adjusted R^2 = 0.168
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, fixed acidity
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, alcohol
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, residual sugar
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, sulphates
# (Step) - Adjusted R^2: This = 0.168; Best = 0.168
# Added feature citric acid with R^2 = 0.169 and adjusted R^2 = 0.168
#
# (Step) Excluded = fixed acidity, residual sugar, sulphates, alcohol
# (Step) Trying fixed acidity...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity
# (Step) - Adjusted R^2: This = 0.172; Best = 0.168
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.173; Adjusted R^2 = 0.172
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, residual sugar
# (Step) - Adjusted R^2: This = 0.172; Best = 0.172
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, sulphates
# (Step) - Adjusted R^2: This = 0.172; Best = 0.172
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, alcohol
# (Step) - Adjusted R^2: This = 0.172; Best = 0.172
# Added feature fixed acidity with R^2 = 0.173 and adjusted R^2 = 0.172
#
# (Step) Excluded = alcohol, residual sugar, sulphates
# (Step) Trying alcohol...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol
# (Step) - Adjusted R^2: This = 0.174; Best = 0.172
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.175; Adjusted R^2 = 0.174
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.174; Best = 0.174
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, sulphates
# (Step) - Adjusted R^2: This = 0.174; Best = 0.174
# Added feature alcohol with R^2 = 0.175 and adjusted R^2 = 0.174
#
# (Step) Excluded = residual sugar, sulphates
# (Step) Trying residual sugar...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.278; Best = 0.174
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.279; Adjusted R^2 = 0.278
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.278; Best = 0.278
# Added feature residual sugar with R^2 = 0.279 and adjusted R^2 = 0.278
#
# (Step) Excluded = sulphates
# (Step) Trying sulphates...
# (Step) - Features = volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates
# (Step) - Adjusted R^2: This = 0.287; Best = 0.278
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.288; Adjusted R^2 = 0.287
# Added feature sulphates with R^2 = 0.288 and adjusted R^2 = 0.287
#
# (Step) Excluded =
#
# Resulting features:
# volatile acidity, free sulfur dioxide, chlorides, red_wine, density, total sulfur dioxide, pH, citric acid, fixed acidity, alcohol, residual sugar, sulphates

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
