# %%
import pandas as pd
import numpy as np
import nltk
import re
import multiprocessing
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from gensim.models.word2vec import Word2Vec
from gensim.models.phrases import Phraser, Phrases
import seaborn as sns
import gensim
import logging
from nltk.corpus import stopwords
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# %matplotlib inline
plt.style.use('ggplot')

# %%
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words
def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    vectors = [] # positions in vector space
    labels = [] # keep track of words to label our data again later
    for word in model.wv.vocab:
        vectors.append(model.wv[word])
        labels.append(word)

    # convert both lists into numpy vectors for reduction
    vectors = np.asarray(vectors)
    labels = np.asarray(labels)

    # reduce using t-SNE
    vectors = np.asarray(vectors)
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels

def plot_with_plotly(x_vals, y_vals, labels, cluster, plot_in_notebook=True):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go


    trace = go.Scatter(x=x_vals, y=y_vals, mode='markers+text', text=labels,textposition='top center')
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')


def plot_with_matplotlib(x_vals, y_vals, labels):
    import matplotlib.pyplot as plt
    import random

    random.seed(0)
    
    plt.figure(figsize=(50, 50))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 25)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))

try:
    get_ipython()
except Exception:
    plot_function = plot_with_matplotlib
else:
    plot_function = plot_with_plotly

# %%
breitbart_csv = 'breitbart_articles_titles.csv'
cnn_csv = 'cnn_articles.csv'
dailywire_csv = 'daily_wire.csv'
reuters_csv = 'reuters_articles.csv'
csv_files = [breitbart_csv, cnn_csv, dailywire_csv, reuters_csv]

dataframes = [None] * len(csv_files)

for i in range(len(dataframes)):
    dataframe = pd.read_csv(csv_files[i])
    dataframes[i] = dataframe.iloc[:100]
dataframes
# Out:
# [    Unnamed: 0                                            product  \
#  0            0  GOP Lawmakers: Joe Biden’s Border Policies a ‘...
#  1            1  Disney World Tickets Sold Out for Spring Break...
#  2            2  Democrat Abigail Spanberger Flip-Flops in Favo...
#  3            3  Joe Biden Prioritizes Migrant Youth ‘Education...
#  4            4  White House Returns Portraits of Clinton, Bush...
#  ..         ...                                                ...
#  95          95  House VA Panel Announces Probe into ‘Extremist...
#  96          96  Report: Lincoln Project Cofounders Knew of Joh...
#  97          97  White House: Joe Biden Opposes Bipartisan Effo...
#  98          98  Exclusive – Rep. Darrell Issa ‘Absolutely’ Sup...
#  99          99  Capitol Security Report Suggests Creation of P...
#
#                                                   link  \
#  0   /politics/2021/03/08/gop-lawmakers-joe-bidens-...
#  1   /politics/2021/03/09/disney-world-tickets-sold...
#  2   /politics/2021/03/09/democrat-abigail-spanberg...
#  3   /politics/2021/03/09/joe-biden-migrant-youth-e...
#  4   /politics/2021/03/09/white-house-returns-portr...
#  ..                                                ...
#  95  /politics/2021/03/08/house-va-panel-announces-...
#  96  /politics/2021/03/08/report-lincoln-project-co...
#  97  /politics/2021/03/08/white-house-joe-biden-opp...
#  98  /politics/2021/03/08/rep-darrell-issa-absolute...
#  99  /politics/2021/03/08/capitol-security-report-s...
#
#                                        article_content     source
#  0   A group of 23 House Republicans has sent a let...  breitbart
#  1   The “happiest place on Earth” will be bursting...  breitbart
#  2   Rep. Abigail Spanberger (D-VA) voted Tuesday a...  breitbart
#  3   President Joe Biden’s administration is focuse...  breitbart
#  4   The White House announced the return of portra...  breitbart
#  ..                                                ...        ...
#  95  The Democrat-controlled House Veterans’ Affair...  breitbart
#  96  Less than a month after The Lincoln Project (T...  breitbart
#  97  President Joe Biden opposes a proposal earning...  breitbart
#  98  ORLANDO, Florida — Rep. Darrell Issa (R-CA) is...  breitbart
#  99  A task force appointed by House Speaker Nancy ...  breitbart
#
#  [100 rows x 5 columns],
#      Unnamed: 0                                            product  \
#  0            0  US is at a tipping point of another Covid-19 s...
#  1            1  He adopted a dog that no one else wanted. It e...
#  2            2  Do we really need pants? And other lessons fro...
#  3            3     Here's how to watch the 2021 NBA All-Star game
#  4            4  Wall Street Journal: Third female former staff...
#  ..         ...                                                ...
#  95          95  Stop sitting still and do these 8 activities t...
#  96          96  Biden administration considers opening additio...
#  97          97  Around 5,000 customers are still without water...
#  98          98  Four sisters in their 80s and 90s reunited to ...
#  99          99  No 'mass exodus' in California during the pand...
#
#                                                   link  \
#  0   https://www.cnn.com/2021/03/07/health/us-coron...
#  1   https://www.cnn.com/2021/03/07/us/rescue-dog-s...
#  2   https://www.cnn.com/2021/03/07/health/sense-of...
#  3   https://www.cnn.com/2021/03/07/us/how-to-watch...
#  4   https://www.cnn.com/2021/03/07/politics/andrew...
#  ..                                                ...
#  95  https://www.cnn.com/2021/03/05/health/how-to-a...
#  96  https://www.cnn.com/2021/03/05/politics/tent-f...
#  97  https://www.cnn.com/2021/03/05/us/jackson-ms-w...
#  98  https://www.cnn.com/2021/03/05/us/sisters-coro...
#  99  https://www.cnn.com/2021/03/05/us/california-s...
#
#                                        article_content source
#  0   But it's not over just yet.Infection numbers, ...    cnn
#  1   Want more inspiring, positive news? Sign up fo...    cnn
#  2   We've missed loved ones and weddings and funer...    cnn
#  3   The 70th annual NBA All-Star Game will air Sun...    cnn
#  4   The Democratic governor already stands accused...    cnn
#  ..                                                ...    ...
#  95  Whether you work from home or not, if your nor...    cnn
#  96  The administration is considering a facility i...    cnn
#  97  Charles Williams, public works director in Jac...    cnn
#  98  Want more inspiring, positive news? Sign up fo...    cnn
#  99  That's despite some headlines and anecdotal cl...    cnn
#
#  [100 rows x 5 columns],
#      Unnamed: 0                                            product  \
#  0            0  YouTube Bans Trump’s Full CPAC Speech Unless U...
#  1            1  ‘Huge Development’: Democrat Sen. Joe Manchin ...
#  2            2  Democrat Congressman Allegedly Failed To Discl...
#  3            3  Heads Of Democratic State Senate, State Assemb...
#  4            4  Biden Signs Executive Order ‘To Make It Easier...
#  ..         ...                                                ...
#  95          95  Orangutan Named Karen Gets COVID-19 Inoculatio...
#  96          96  Disney Closing 60 Bricks-And-Mortar Stores\nBy...
#  97          97  Reports: Capitol Police Request Extension Of N...
#  98          98  ‘You Gotta Wear Heels’: Staffers Describe ‘The...
#  99          99  ‘We Should Give Her The Nobel Prize In Economi...
#
#                                                   link  \
#  0   https://www.dailywire.com/news/youtube-bans-tr...
#  1   https://www.dailywire.com/news/huge-developmen...
#  2   https://www.dailywire.com/news/democrat-congre...
#  3   https://www.dailywire.com/news/heads-of-democr...
#  4   https://www.dailywire.com/news/biden-signs-exe...
#  ..                                                ...
#  95  https://www.dailywire.com/news/orangutan-named...
#  96  https://www.dailywire.com/news/disney-closing-...
#  97  https://www.dailywire.com/news/reports-capitol...
#  98  https://www.dailywire.com/news/you-gotta-wear-...
#  99  https://www.dailywire.com/news/we-should-give-...
#
#                                        article_content      source
#  0   YouTube has banned the platforming of former P...  daily wire
#  1   Democrat Senator Joe Manchin (WV) appears to h...  daily wire
#  2   Rep. Tom Malinowski (D-NJ) is facing heat foll...  daily wire
#  3   The Democratic leaders of the New York State A...  daily wire
#  4   President Joe Biden signed an executive order ...  daily wire
#  ..                                                ...         ...
#  95  “That big sigh of relief isn’t going to come u...  daily wire
#  96  The Walt Disney Company announced on Wednesday...  daily wire
#  97  The United States Capitol Police Department ha...  daily wire
#  98  Current and former staffers of New York Gov. A...  daily wire
#  99  After Rep. Alexandria Ocasio-Cortez (D-NY) cri...  daily wire
#
#  [100 rows x 5 columns],
#      Unnamed: 0                                            product  \
#  0            0  Google to review adverts for Myanmar military-...
#  1            1  Germany plays down scale of vaccine boost in A...
#  2            2  Serving UK police officer arrested over missin...
#  3            3  EU responds to UK summons after fresh vaccine ...
#  4            4  South Korean hospitals extract extra COVID vac...
#  ..         ...                                                ...
#  95          95  Kremlin rejects U.S. allegation Russia is tryi...
#  96          96  Poland to resume some logging in ancient Bialo...
#  97          97  China launches COVID-19 vaccination certificat...
#  98          98  Irked Thai PM sprays reporters with hand sanit...
#  99          99  India summons British envoy over 'unwarranted'...
#
#                                                   link  \
#  0   https://www.reuters.com/article/us-myanmar-pol...
#  1   https://www.reuters.com/article/us-health-coro...
#  2   https://www.reuters.com/article/us-britain-cri...
#  3   https://www.reuters.com/article/us-britain-eu-...
#  4   https://www.reuters.com/article/us-health-coro...
#  ..                                                ...
#  95  https://www.reuters.com/article/us-usa-russia-...
#  96  https://www.reuters.com/article/us-poland-eu-b...
#  97  https://www.reuters.com/article/us-health-coro...
#  98  https://www.reuters.com/article/us-thailand-po...
#  99  https://www.reuters.com/article/us-india-farms...
#
#                                        article_content   source
#  0   SINGAPORE (Reuters) - Google said on Wednesday...  Reuters
#  1   BERLIN (Reuters) - Far more people in Germany ...  Reuters
#  2   LONDON (Reuters) - A serving British police of...  Reuters
#  3   BRUSSELS (Reuters) - The European Union respon...  Reuters
#  4   SEOUL (Reuters) - In a handful of South Korean...  Reuters
#  ..                                                ...      ...
#  95  MOSCOW (Reuters) - The Kremlin on Tuesday rebu...  Reuters
#  96  WARSAW (Reuters) - Poland will resume some log...  Reuters
#  97  BEIJING (Reuters) - China has launched a digit...  Reuters
#  98  BANGKOK (Reuters) - Thai Prime Minister Prayut...  Reuters
#  99  NEW DELHI (Reuters) - India’s foreign ministry...  Reuters
#
#  [100 rows x 5 columns]]

# %%
df = pd.concat(dataframes)
df = df.drop('Unnamed: 0',axis=1)
df
# Out:
#                                               product  \
# 0   GOP Lawmakers: Joe Biden’s Border Policies a ‘...
# 1   Disney World Tickets Sold Out for Spring Break...
# 2   Democrat Abigail Spanberger Flip-Flops in Favo...
# 3   Joe Biden Prioritizes Migrant Youth ‘Education...
# 4   White House Returns Portraits of Clinton, Bush...
# ..                                                ...
# 95  Kremlin rejects U.S. allegation Russia is tryi...
# 96  Poland to resume some logging in ancient Bialo...
# 97  China launches COVID-19 vaccination certificat...
# 98  Irked Thai PM sprays reporters with hand sanit...
# 99  India summons British envoy over 'unwarranted'...
#
#                                                  link  \
# 0   /politics/2021/03/08/gop-lawmakers-joe-bidens-...
# 1   /politics/2021/03/09/disney-world-tickets-sold...
# 2   /politics/2021/03/09/democrat-abigail-spanberg...
# 3   /politics/2021/03/09/joe-biden-migrant-youth-e...
# 4   /politics/2021/03/09/white-house-returns-portr...
# ..                                                ...
# 95  https://www.reuters.com/article/us-usa-russia-...
# 96  https://www.reuters.com/article/us-poland-eu-b...
# 97  https://www.reuters.com/article/us-health-coro...
# 98  https://www.reuters.com/article/us-thailand-po...
# 99  https://www.reuters.com/article/us-india-farms...
#
#                                       article_content     source
# 0   A group of 23 House Republicans has sent a let...  breitbart
# 1   The “happiest place on Earth” will be bursting...  breitbart
# 2   Rep. Abigail Spanberger (D-VA) voted Tuesday a...  breitbart
# 3   President Joe Biden’s administration is focuse...  breitbart
# 4   The White House announced the return of portra...  breitbart
# ..                                                ...        ...
# 95  MOSCOW (Reuters) - The Kremlin on Tuesday rebu...    Reuters
# 96  WARSAW (Reuters) - Poland will resume some log...    Reuters
# 97  BEIJING (Reuters) - China has launched a digit...    Reuters
# 98  BANGKOK (Reuters) - Thai Prime Minister Prayut...    Reuters
# 99  NEW DELHI (Reuters) - India’s foreign ministry...    Reuters
#
# [400 rows x 4 columns]

# %%
df = df.drop_duplicates()
df = df.dropna()

# %%
raw_corpus = ''
row_count = 0
for row in df.article_content:    
    print('Adding to raw_corpus... \n row_num is {row_count}'.format(row_count=row_count))
    row_count += 1
    raw_corpus += row
# Out:
# Adding to raw_corpus...
#  row_num is 0
# Adding to raw_corpus...
#  row_num is 1
# Adding to raw_corpus...
#  row_num is 2
# Adding to raw_corpus...
#  row_num is 3
# Adding to raw_corpus...
#  row_num is 4
# Adding to raw_corpus...
#  row_num is 5
# Adding to raw_corpus...
#  row_num is 6
# Adding to raw_corpus...
#  row_num is 7
# Adding to raw_corpus...
#  row_num is 8
# Adding to raw_corpus...
#  row_num is 9
# Adding to raw_corpus...
#  row_num is 10
# Adding to raw_corpus...
#  row_num is 11
# Adding to raw_corpus...
#  row_num is 12
# Adding to raw_corpus...
#  row_num is 13
# Adding to raw_corpus...
#  row_num is 14
# Adding to raw_corpus...
#  row_num is 15
# Adding to raw_corpus...
#  row_num is 16
# Adding to raw_corpus...
#  row_num is 17
# Adding to raw_corpus...
#  row_num is 18
# Adding to raw_corpus...
#  row_num is 19
# Adding to raw_corpus...
#  row_num is 20
# Adding to raw_corpus...
#  row_num is 21
# Adding to raw_corpus...
#  row_num is 22
# Adding to raw_corpus...
#  row_num is 23
# Adding to raw_corpus...
#  row_num is 24
# Adding to raw_corpus...
#  row_num is 25
# Adding to raw_corpus...
#  row_num is 26
# Adding to raw_corpus...
#  row_num is 27
# Adding to raw_corpus...
#  row_num is 28
# Adding to raw_corpus...
#  row_num is 29
# Adding to raw_corpus...
#  row_num is 30
# Adding to raw_corpus...
#  row_num is 31
# Adding to raw_corpus...
#  row_num is 32
# Adding to raw_corpus...
#  row_num is 33
# Adding to raw_corpus...
#  row_num is 34
# Adding to raw_corpus...
#  row_num is 35
# Adding to raw_corpus...
#  row_num is 36
# Adding to raw_corpus...
#  row_num is 37
# Adding to raw_corpus...
#  row_num is 38
# Adding to raw_corpus...
#  row_num is 39
# Adding to raw_corpus...
#  row_num is 40
# Adding to raw_corpus...
#  row_num is 41
# Adding to raw_corpus...
#  row_num is 42
# Adding to raw_corpus...
#  row_num is 43
# Adding to raw_corpus...
#  row_num is 44
# Adding to raw_corpus...
#  row_num is 45
# Adding to raw_corpus...
#  row_num is 46
# Adding to raw_corpus...
#  row_num is 47
# Adding to raw_corpus...
#  row_num is 48
# Adding to raw_corpus...
#  row_num is 49
# Adding to raw_corpus...
#  row_num is 50
# Adding to raw_corpus...
#  row_num is 51
# Adding to raw_corpus...
#  row_num is 52
# Adding to raw_corpus...
#  row_num is 53
# Adding to raw_corpus...
#  row_num is 54
# Adding to raw_corpus...
#  row_num is 55
# Adding to raw_corpus...
#  row_num is 56
# Adding to raw_corpus...
#  row_num is 57
# Adding to raw_corpus...
#  row_num is 58
# Adding to raw_corpus...
#  row_num is 59
# Adding to raw_corpus...
#  row_num is 60
# Adding to raw_corpus...
#  row_num is 61
# Adding to raw_corpus...
#  row_num is 62
# Adding to raw_corpus...
#  row_num is 63
# Adding to raw_corpus...
#  row_num is 64
# Adding to raw_corpus...
#  row_num is 65
# Adding to raw_corpus...
#  row_num is 66
# Adding to raw_corpus...
#  row_num is 67
# Adding to raw_corpus...
#  row_num is 68
# Adding to raw_corpus...
#  row_num is 69
# Adding to raw_corpus...
#  row_num is 70
# Adding to raw_corpus...
#  row_num is 71
# Adding to raw_corpus...
#  row_num is 72
# Adding to raw_corpus...
#  row_num is 73
# Adding to raw_corpus...
#  row_num is 74
# Adding to raw_corpus...
#  row_num is 75
# Adding to raw_corpus...
#  row_num is 76
# Adding to raw_corpus...
#  row_num is 77
# Adding to raw_corpus...
#  row_num is 78
# Adding to raw_corpus...
#  row_num is 79
# Adding to raw_corpus...
#  row_num is 80
# Adding to raw_corpus...
#  row_num is 81
# Adding to raw_corpus...
#  row_num is 82
# Adding to raw_corpus...
#  row_num is 83
# Adding to raw_corpus...
#  row_num is 84
# Adding to raw_corpus...
#  row_num is 85
# Adding to raw_corpus...
#  row_num is 86
# Adding to raw_corpus...
#  row_num is 87
# Adding to raw_corpus...
#  row_num is 88
# Adding to raw_corpus...
#  row_num is 89
# Adding to raw_corpus...
#  row_num is 90
# Adding to raw_corpus...
#  row_num is 91
# Adding to raw_corpus...
#  row_num is 92
# Adding to raw_corpus...
#  row_num is 93
# Adding to raw_corpus...
#  row_num is 94
# Adding to raw_corpus...
#  row_num is 95
# Adding to raw_corpus...
#  row_num is 96
# Adding to raw_corpus...
#  row_num is 97
# Adding to raw_corpus...
#  row_num is 98
# Adding to raw_corpus...
#  row_num is 99
# Adding to raw_corpus...
#  row_num is 100
# Adding to raw_corpus...
#  row_num is 101
# Adding to raw_corpus...
#  row_num is 102
# Adding to raw_corpus...
#  row_num is 103
# Adding to raw_corpus...
#  row_num is 104
# Adding to raw_corpus...
#  row_num is 105
# Adding to raw_corpus...
#  row_num is 106
# Adding to raw_corpus...
#  row_num is 107
# Adding to raw_corpus...
#  row_num is 108
# Adding to raw_corpus...
#  row_num is 109
# Adding to raw_corpus...
#  row_num is 110
# Adding to raw_corpus...
#  row_num is 111
# Adding to raw_corpus...
#  row_num is 112
# Adding to raw_corpus...
#  row_num is 113
# Adding to raw_corpus...
#  row_num is 114
# Adding to raw_corpus...
#  row_num is 115
# Adding to raw_corpus...
#  row_num is 116
# Adding to raw_corpus...
#  row_num is 117
# Adding to raw_corpus...
#  row_num is 118
# Adding to raw_corpus...
#  row_num is 119
# Adding to raw_corpus...
#  row_num is 120
# Adding to raw_corpus...
#  row_num is 121
# Adding to raw_corpus...
#  row_num is 122
# Adding to raw_corpus...
#  row_num is 123
# Adding to raw_corpus...
#  row_num is 124
# Adding to raw_corpus...
#  row_num is 125
# Adding to raw_corpus...
#  row_num is 126
# Adding to raw_corpus...
#  row_num is 127
# Adding to raw_corpus...
#  row_num is 128
# Adding to raw_corpus...
#  row_num is 129
# Adding to raw_corpus...
#  row_num is 130
# Adding to raw_corpus...
#  row_num is 131
# Adding to raw_corpus...
#  row_num is 132
# Adding to raw_corpus...
#  row_num is 133
# Adding to raw_corpus...
#  row_num is 134
# Adding to raw_corpus...
#  row_num is 135
# Adding to raw_corpus...
#  row_num is 136
# Adding to raw_corpus...
#  row_num is 137
# Adding to raw_corpus...
#  row_num is 138
# Adding to raw_corpus...
#  row_num is 139
# Adding to raw_corpus...
#  row_num is 140
# Adding to raw_corpus...
#  row_num is 141
# Adding to raw_corpus...
#  row_num is 142
# Adding to raw_corpus...
#  row_num is 143
# Adding to raw_corpus...
#  row_num is 144
# Adding to raw_corpus...
#  row_num is 145
# Adding to raw_corpus...
#  row_num is 146
# Adding to raw_corpus...
#  row_num is 147
# Adding to raw_corpus...
#  row_num is 148
# Adding to raw_corpus...
#  row_num is 149
# Adding to raw_corpus...
#  row_num is 150
# Adding to raw_corpus...
#  row_num is 151
# Adding to raw_corpus...
#  row_num is 152
# Adding to raw_corpus...
#  row_num is 153
# Adding to raw_corpus...
#  row_num is 154
# Adding to raw_corpus...
#  row_num is 155
# Adding to raw_corpus...
#  row_num is 156
# Adding to raw_corpus...
#  row_num is 157
# Adding to raw_corpus...
#  row_num is 158
# Adding to raw_corpus...
#  row_num is 159
# Adding to raw_corpus...
#  row_num is 160
# Adding to raw_corpus...
#  row_num is 161
# Adding to raw_corpus...
#  row_num is 162
# Adding to raw_corpus...
#  row_num is 163
# Adding to raw_corpus...
#  row_num is 164
# Adding to raw_corpus...
#  row_num is 165
# Adding to raw_corpus...
#  row_num is 166
# Adding to raw_corpus...
#  row_num is 167
# Adding to raw_corpus...
#  row_num is 168
# Adding to raw_corpus...
#  row_num is 169
# Adding to raw_corpus...
#  row_num is 170
# Adding to raw_corpus...
#  row_num is 171
# Adding to raw_corpus...
#  row_num is 172
# Adding to raw_corpus...
#  row_num is 173
# Adding to raw_corpus...
#  row_num is 174
# Adding to raw_corpus...
#  row_num is 175
# Adding to raw_corpus...
#  row_num is 176
# Adding to raw_corpus...
#  row_num is 177
# Adding to raw_corpus...
#  row_num is 178
# Adding to raw_corpus...
#  row_num is 179
# Adding to raw_corpus...
#  row_num is 180
# Adding to raw_corpus...
#  row_num is 181
# Adding to raw_corpus...
#  row_num is 182
# Adding to raw_corpus...
#  row_num is 183
# Adding to raw_corpus...
#  row_num is 184
# Adding to raw_corpus...
#  row_num is 185
# Adding to raw_corpus...
#  row_num is 186
# Adding to raw_corpus...
#  row_num is 187
# Adding to raw_corpus...
#  row_num is 188
# Adding to raw_corpus...
#  row_num is 189
# Adding to raw_corpus...
#  row_num is 190
# Adding to raw_corpus...
#  row_num is 191
# Adding to raw_corpus...
#  row_num is 192
# Adding to raw_corpus...
#  row_num is 193
# Adding to raw_corpus...
#  row_num is 194
# Adding to raw_corpus...
#  row_num is 195
# Adding to raw_corpus...
#  row_num is 196
# Adding to raw_corpus...
#  row_num is 197
# Adding to raw_corpus...
#  row_num is 198
# Adding to raw_corpus...
#  row_num is 199
# Adding to raw_corpus...
#  row_num is 200
# Adding to raw_corpus...
#  row_num is 201
# Adding to raw_corpus...
#  row_num is 202
# Adding to raw_corpus...
#  row_num is 203
# Adding to raw_corpus...
#  row_num is 204
# Adding to raw_corpus...
#  row_num is 205
# Adding to raw_corpus...
#  row_num is 206
# Adding to raw_corpus...
#  row_num is 207
# Adding to raw_corpus...
#  row_num is 208
# Adding to raw_corpus...
#  row_num is 209
# Adding to raw_corpus...
#  row_num is 210
# Adding to raw_corpus...
#  row_num is 211
# Adding to raw_corpus...
#  row_num is 212
# Adding to raw_corpus...
#  row_num is 213
# Adding to raw_corpus...
#  row_num is 214
# Adding to raw_corpus...
#  row_num is 215
# Adding to raw_corpus...
#  row_num is 216
# Adding to raw_corpus...
#  row_num is 217
# Adding to raw_corpus...
#  row_num is 218
# Adding to raw_corpus...
#  row_num is 219
# Adding to raw_corpus...
#  row_num is 220
# Adding to raw_corpus...
#  row_num is 221
# Adding to raw_corpus...
#  row_num is 222
# Adding to raw_corpus...
#  row_num is 223
# Adding to raw_corpus...
#  row_num is 224
# Adding to raw_corpus...
#  row_num is 225
# Adding to raw_corpus...
#  row_num is 226
# Adding to raw_corpus...
#  row_num is 227
# Adding to raw_corpus...
#  row_num is 228
# Adding to raw_corpus...
#  row_num is 229
# Adding to raw_corpus...
#  row_num is 230
# Adding to raw_corpus...
#  row_num is 231
# Adding to raw_corpus...
#  row_num is 232
# Adding to raw_corpus...
#  row_num is 233
# Adding to raw_corpus...
#  row_num is 234
# Adding to raw_corpus...
#  row_num is 235
# Adding to raw_corpus...
#  row_num is 236
# Adding to raw_corpus...
#  row_num is 237
# Adding to raw_corpus...
#  row_num is 238
# Adding to raw_corpus...
#  row_num is 239
# Adding to raw_corpus...
#  row_num is 240
# Adding to raw_corpus...
#  row_num is 241
# Adding to raw_corpus...
#  row_num is 242
# Adding to raw_corpus...
#  row_num is 243
# Adding to raw_corpus...
#  row_num is 244
# Adding to raw_corpus...
#  row_num is 245
# Adding to raw_corpus...
#  row_num is 246
# Adding to raw_corpus...
#  row_num is 247
# Adding to raw_corpus...
#  row_num is 248
# Adding to raw_corpus...
#  row_num is 249
# Adding to raw_corpus...
#  row_num is 250
# Adding to raw_corpus...
#  row_num is 251
# Adding to raw_corpus...
#  row_num is 252
# Adding to raw_corpus...
#  row_num is 253
# Adding to raw_corpus...
#  row_num is 254
# Adding to raw_corpus...
#  row_num is 255
# Adding to raw_corpus...
#  row_num is 256
# Adding to raw_corpus...
#  row_num is 257
# Adding to raw_corpus...
#  row_num is 258
# Adding to raw_corpus...
#  row_num is 259
# Adding to raw_corpus...
#  row_num is 260
# Adding to raw_corpus...
#  row_num is 261
# Adding to raw_corpus...
#  row_num is 262
# Adding to raw_corpus...
#  row_num is 263
# Adding to raw_corpus...
#  row_num is 264
# Adding to raw_corpus...
#  row_num is 265
# Adding to raw_corpus...
#  row_num is 266
# Adding to raw_corpus...
#  row_num is 267
# Adding to raw_corpus...
#  row_num is 268
# Adding to raw_corpus...
#  row_num is 269
# Adding to raw_corpus...
#  row_num is 270
# Adding to raw_corpus...
#  row_num is 271
# Adding to raw_corpus...
#  row_num is 272
# Adding to raw_corpus...
#  row_num is 273
# Adding to raw_corpus...
#  row_num is 274
# Adding to raw_corpus...
#  row_num is 275
# Adding to raw_corpus...
#  row_num is 276
# Adding to raw_corpus...
#  row_num is 277
# Adding to raw_corpus...
#  row_num is 278
# Adding to raw_corpus...
#  row_num is 279
# Adding to raw_corpus...
#  row_num is 280
# Adding to raw_corpus...
#  row_num is 281
# Adding to raw_corpus...
#  row_num is 282
# Adding to raw_corpus...
#  row_num is 283
# Adding to raw_corpus...
#  row_num is 284
# Adding to raw_corpus...
#  row_num is 285
# Adding to raw_corpus...
#  row_num is 286
# Adding to raw_corpus...
#  row_num is 287
# Adding to raw_corpus...
#  row_num is 288
# Adding to raw_corpus...
#  row_num is 289
# Adding to raw_corpus...
#  row_num is 290
# Adding to raw_corpus...
#  row_num is 291
# Adding to raw_corpus...
#  row_num is 292
# Adding to raw_corpus...
#  row_num is 293
# Adding to raw_corpus...
#  row_num is 294
# Adding to raw_corpus...
#  row_num is 295
# Adding to raw_corpus...
#  row_num is 296
# Adding to raw_corpus...
#  row_num is 297
# Adding to raw_corpus...
#  row_num is 298
# Adding to raw_corpus...
#  row_num is 299
# Adding to raw_corpus...
#  row_num is 300
# Adding to raw_corpus...
#  row_num is 301
# Adding to raw_corpus...
#  row_num is 302
# Adding to raw_corpus...
#  row_num is 303
# Adding to raw_corpus...
#  row_num is 304
# Adding to raw_corpus...
#  row_num is 305
# Adding to raw_corpus...
#  row_num is 306
# Adding to raw_corpus...
#  row_num is 307
# Adding to raw_corpus...
#  row_num is 308
# Adding to raw_corpus...
#  row_num is 309
# Adding to raw_corpus...
#  row_num is 310
# Adding to raw_corpus...
#  row_num is 311
# Adding to raw_corpus...
#  row_num is 312
# Adding to raw_corpus...
#  row_num is 313
# Adding to raw_corpus...
#  row_num is 314
# Adding to raw_corpus...
#  row_num is 315
# Adding to raw_corpus...
#  row_num is 316
# Adding to raw_corpus...
#  row_num is 317
# Adding to raw_corpus...
#  row_num is 318
# Adding to raw_corpus...
#  row_num is 319
# Adding to raw_corpus...
#  row_num is 320
# Adding to raw_corpus...
#  row_num is 321
# Adding to raw_corpus...
#  row_num is 322
# Adding to raw_corpus...
#  row_num is 323
# Adding to raw_corpus...
#  row_num is 324
# Adding to raw_corpus...
#  row_num is 325
# Adding to raw_corpus...
#  row_num is 326
# Adding to raw_corpus...
#  row_num is 327
# Adding to raw_corpus...
#  row_num is 328
# Adding to raw_corpus...
#  row_num is 329
# Adding to raw_corpus...
#  row_num is 330
# Adding to raw_corpus...
#  row_num is 331
# Adding to raw_corpus...
#  row_num is 332
# Adding to raw_corpus...
#  row_num is 333
# Adding to raw_corpus...
#  row_num is 334
# Adding to raw_corpus...
#  row_num is 335
# Adding to raw_corpus...
#  row_num is 336
# Adding to raw_corpus...
#  row_num is 337
# Adding to raw_corpus...
#  row_num is 338
# Adding to raw_corpus...
#  row_num is 339
# Adding to raw_corpus...
#  row_num is 340
# Adding to raw_corpus...
#  row_num is 341
# Adding to raw_corpus...
#  row_num is 342
# Adding to raw_corpus...
#  row_num is 343
# Adding to raw_corpus...
#  row_num is 344
# Adding to raw_corpus...
#  row_num is 345
# Adding to raw_corpus...
#  row_num is 346
# Adding to raw_corpus...
#  row_num is 347
# Adding to raw_corpus...
#  row_num is 348
# Adding to raw_corpus...
#  row_num is 349
# Adding to raw_corpus...
#  row_num is 350
# Adding to raw_corpus...
#  row_num is 351
# Adding to raw_corpus...
#  row_num is 352
# Adding to raw_corpus...
#  row_num is 353
# Adding to raw_corpus...
#  row_num is 354
# Adding to raw_corpus...
#  row_num is 355
# Adding to raw_corpus...
#  row_num is 356
# Adding to raw_corpus...
#  row_num is 357
# Adding to raw_corpus...
#  row_num is 358
# Adding to raw_corpus...
#  row_num is 359
# Adding to raw_corpus...
#  row_num is 360
# Adding to raw_corpus...
#  row_num is 361
# Adding to raw_corpus...
#  row_num is 362
# Adding to raw_corpus...
#  row_num is 363

# %%
raw_corpus = raw_corpus.replace(u'\xa0', u' ')

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
raw_sentences = tokenizer.tokenize(raw_corpus)
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence.lower()))

# %%
stopWords = list(stopwords.words('english'))
sent_remove_stopwords = []
for sent in sentences:
    append_sent = []
    for word in sent:
        if word not in stopWords:
            append_sent.append(word)
    sent_remove_stopwords.append(append_sent)

# %%
phrases = Phrases(sent_remove_stopwords, common_terms=stopWords)
bigram = Phraser(phrases)
# Out:
# 2021-03-13 22:02:16,691 : INFO : collecting all words and their counts
# 2021-03-13 22:02:16,692 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2021-03-13 22:02:16,874 : INFO : collected 116609 word types from a corpus of 133632 words (unigram + bigrams) and 6018 sentences
# 2021-03-13 22:02:16,874 : INFO : using 116609 counts as vocab in Phrases<0 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000>
# 2021-03-13 22:02:16,875 : INFO : source_vocab length 116609
# 2021-03-13 22:02:17,775 : INFO : Phraser built with 757 phrasegrams

# %%
all_sentences = list(bigram[sent_remove_stopwords])

# %%
all_sentences[:1000]
# Out:
# [['group',
#   'house',
#   'republicans',
#   'sent',
#   'letter',
#   'department',
#   'homeland',
#   'security',
#   'dhs',
#   'secretary',
#   'alejandro',
#   'mayorkas',
#   'demanding',
#   'answers',
#   'many',
#   'border_crossers',
#   'testing',
#   'positive',
#   'chinese',
#   'coronavirus',
#   'subsequently',
#   'released',
#   'united_states',
#   'interior',
#   'letter',
#   'led',
#   'rep',
#   'michael',
#   'burgess',
#   'r',
#   'tx',
#   'calls',
#   'president',
#   'joe_biden',
#   'policies',
#   'u',
#   'mexico',
#   'border',
#   'thousands',
#   'border_crossers',
#   'migrants',
#   'released',
#   'nation',
#   'interior',
#   'enrolled',
#   'remain',
#   'mexico',
#   'program',
#   'tested',
#   'coronavirus',
#   'others',
#   'released',
#   'sometimes',
#   'tested',
#   'local',
#   'communities',
#   'sent',
#   'way',
#   'regardless',
#   'test',
#   'results',
#   'reports',
#   'least',
#   'migrants',
#   'tested',
#   'positive',
#   'coronavirus',
#   'released',
#   'united_states',
#   'letter',
#   'states',
#   'reports',
#   'last_week',
#   'confirmed',
#   'border_crossers',
#   'released',
#   'u',
#   'interior',
#   'tested',
#   'positive',
#   'coronavirus'],
#  ['even',
#   'positive',
#   'result',
#   'border_crossers',
#   'free',
#   'continue',
#   'traveling',
#   'u',
#   'house',
#   'republicans',
#   'said',
#   'restart',
#   'catch',
#   'release',
#   'program',
#   'midst',
#   'pandemic',
#   'guaranteed',
#   'super',
#   'spreader',
#   'event',
#   'write',
#   'historical',
#   'precedent',
#   'indicates',
#   'illegal',
#   'border',
#   'crossings',
#   'may',
#   'increase',
#   'per',
#   'month',
#   'spring'],
#  ['due',
#   'continued',
#   'need',
#   'social',
#   'distancing',
#   'dhs',
#   'facilities',
#   'quickly',
#   'reach',
#   'capacity'],
#  ['even',
#   'efforts',
#   'social',
#   'distance',
#   'reporting',
#   'states',
#   'migrants',
#   'already',
#   'held',
#   'crowded',
#   'spaces',
#   'processed'],
#  ['emphasis',
#   'added',
#   'coupled',
#   'lack',
#   'coronavirus',
#   'testing',
#   'along',
#   'southern',
#   'border',
#   'guaranteed',
#   'super',
#   'spreader',
#   'event'],
#  ['least',
#   'individuals',
#   'encountered',
#   'along',
#   'southern',
#   'border',
#   'must',
#   'tested',
#   'coronavirus',
#   'provided',
#   'personal',
#   'protective',
#   'equipment'],
#  ['emphasis',
#   'added',
#   'among',
#   'questions',
#   'asked',
#   'mayorkas',
#   'house',
#   'republicans',
#   'want',
#   'know',
#   'border_crossers',
#   'turned',
#   'away',
#   'center',
#   'disease',
#   'control',
#   'title',
#   'order',
#   'helped',
#   'stem',
#   'flow',
#   'illegal',
#   'immigration',
#   'u',
#   'allowing',
#   'federal',
#   'officials',
#   'quickly',
#   'return',
#   'border_crossers',
#   'back',
#   'native',
#   'countries',
#   'lawmakers',
#   'also',
#   'want',
#   'know',
#   'many',
#   'border_crossers',
#   'released',
#   'u',
#   'interior',
#   'well',
#   'many',
#   'border_crossers',
#   'released',
#   'eventually',
#   'test',
#   'positive',
#   'coronavirus',
#   'signatories',
#   'letter',
#   'include',
#   'full',
#   'letter',
#   'read',
#   'letter',
#   'mayorkas',
#   'title',
#   'john',
#   'binderdays',
#   'ago',
#   'texas',
#   'gov'],
#  ['greg',
#   'abbott',
#   'r',
#   'announced',
#   'deploying',
#   'state',
#   'national',
#   'guard',
#   'troops',
#   'high',
#   'risk',
#   'areas',
#   'u',
#   'mexico',
#   'border',
#   'texas',
#   'supports',
#   'legal',
#   'immigration',
#   'accomplice',
#   'open',
#   'border',
#   'policies',
#   'cause',
#   'rather',
#   'prevent',
#   'humanitarian',
#   'crisis',
#   'state',
#   'endanger',
#   'lives',
#   'texans',
#   'abbott',
#   'wrote',
#   'statement',
#   'title',
#   'cited',
#   'lawmakers',
#   'letter',
#   'successfully',
#   'expelled',
#   'nearly',
#   'border_crossers',
#   'u',
#   'since',
#   'march'],
#  ['last',
#   'four',
#   'months',
#   'alone',
#   'border_crossers',
#   'expelled',
#   'deported',
#   'monthly',
#   'title',
#   'breitbart_news',
#   'exclusively',
#   'reported',
#   'biden_administration',
#   'considering',
#   'ending',
#   'title',
#   'gop',
#   'lawmakers',
#   'previously',
#   'said',
#   'would',
#   'invite',
#   'surge',
#   'illegal',
#   'immigration',
#   'thanks',
#   'biden',
#   'ending',
#   'remain',
#   'mexico',
#   'program',
#   'canceling',
#   'number',
#   'cooperative',
#   'asylum',
#   'agreements',
#   'federal',
#   'officials',
#   'released',
#   'border_crossers',
#   'u',
#   'first',
#   'four',
#   'days',
#   'month',
#   'breitbart_news',
#   'reported'],
#  ['since',
#   'february',
#   'dhs',
#   'released',
#   'remain',
#   'mexico',
#   'migrants',
#   'u',
#   'biden',
#   'catch',
#   'release',
#   'policy',
#   'proven',
#   'unpopular',
#   'americans'],
#  ['poll',
#   'conducted',
#   'last',
#   'month',
#   'nearly',
#   'voters',
#   'percent',
#   'said',
#   'border_crossers',
#   'returned',
#   'mexico',
#   'remain',
#   'mexico',
#   'program',
#   'percent',
#   'said',
#   'released',
#   'u',
#   'interior',
#   'john',
#   'binder',
#   'reporter',
#   'breitbart_news'],
#  ['email', 'jbinder', 'breitbart', 'com'],
#  ['follow_twitter'],
#  ['immigrationpoliticsalejandro',
#   'mayorkascatch',
#   'releasecoronavirusdhsillegal',
#   'immigrationjoe',
#   'bidenopen',
#   'bordersremain',
#   'mexicotitle',
#   'u',
#   'mexico',
#   'border',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartthe',
#   'happiest',
#   'place',
#   'earth',
#   'bursting',
#   'seams',
#   'spring',
#   'breakers',
#   'sell',
#   'tickets',
#   'disney',
#   'world',
#   'next',
#   'week',
#   'various',
#   'walt',
#   'disney',
#   'world',
#   'parks',
#   'operating',
#   'reduced',
#   'capacity',
#   'florida',
#   'health',
#   'guidelines',
#   'lack',
#   'willing',
#   'visitors'],
#  ['parks',
#   'reopened',
#   'july',
#   'march',
#   'closure',
#   'due',
#   'coronavirus',
#   'pandemic',
#   'ongoing',
#   'health',
#   'concerns',
#   'stifled',
#   'flow',
#   'would',
#   'vacationers',
#   'january',
#   'saw',
#   'hard',
#   'slump',
#   'tourist',
#   'traffic',
#   'marking',
#   'first',
#   'month',
#   'month',
#   'decline',
#   'tdt',
#   'collections',
#   'since',
#   'hit',
#   'rock',
#   'bottom',
#   'april',
#   'according',
#   'orange',
#   'county',
#   'comptroller',
#   'phil',
#   'diamond',
#   'slump',
#   'seems'],
#  ['time',
#   'writing',
#   'limited',
#   'tickets',
#   'available',
#   'various',
#   'walt',
#   'disney',
#   'world',
#   'parks',
#   'orlando',
#   'florida',
#   'remainder',
#   'week'],
#  ['next',
#   'week',
#   'already',
#   'completely',
#   'sold',
#   'disney',
#   'continue',
#   'host',
#   'visitors',
#   'total',
#   'capacity',
#   'additional',
#   'safety',
#   'measures',
#   'place',
#   'foreseeable',
#   'future'],
#  ['even',
#   'plans',
#   'month',
#   'world',
#   'magical',
#   'celebration',
#   'remain',
#   'place',
#   'begin',
#   'october',
#   'taken',
#   'enhanced',
#   'health',
#   'safety',
#   'measures',
#   'guests',
#   'cast',
#   'members',
#   'disney',
#   'world',
#   'official',
#   'website',
#   'says',
#   'accompanying',
#   'warning',
#   'ongoing',
#   'health',
#   'concerns',
#   'instructions',
#   'regarding',
#   'conduct',
#   'requirements',
#   'premises'],
#  ['help',
#   'keep',
#   'healthy',
#   'healthpoliticspre',
#   'viralcoronavirusdisney',
#   'worldfloridaorlandotourism',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartrep'],
#  ['abigail',
#   'spanberger',
#   'va',
#   'voted',
#   'tuesday',
#   'motion',
#   'would',
#   'blocked',
#   'labor',
#   'unions',
#   'encouraging',
#   'illegal_aliens',
#   'join',
#   'labor',
#   'unions'],
#  ['spanberger', 'voted', 'favor', 'motion', 'last_year', 'rep'],
#  ['jim',
#   'banks',
#   'r',
#   'chairman',
#   'republican',
#   'study',
#   'committee',
#   'unveiled',
#   'motion',
#   'recommit',
#   'protecting',
#   'right',
#   'organize',
#   'pro',
#   'act'],
#  ['pro',
#   'act',
#   'passed',
#   'house',
#   'tuesday',
#   'night',
#   'legislation',
#   'would',
#   'essentially',
#   'curb',
#   'states',
#   'right',
#   'work',
#   'laws'],
#  ['right',
#   'work',
#   'laws',
#   'allow',
#   'workers',
#   'choose',
#   'whether',
#   'join',
#   'union',
#   'protect',
#   'retribution',
#   'wish',
#   'join',
#   'union',
#   'passed',
#   'house',
#   'floor',
#   'motion',
#   'recommit',
#   'would',
#   'send',
#   'bill',
#   'back',
#   'house',
#   'education',
#   'labor',
#   'committee',
#   'instructions',
#   'include',
#   'provision',
#   'banning',
#   'illegal_aliens',
#   'communications',
#   'working',
#   'labor',
#   'union',
#   'banks',
#   'said',
#   'pro',
#   'act',
#   'prioritizes',
#   'interests',
#   'illegal_aliens',
#   'union',
#   'bosses',
#   'hoosier',
#   'conservative',
#   'noted',
#   'family',
#   'rich',
#   'history',
#   'working',
#   'labor',
#   'unions',
#   'however',
#   'said',
#   'travesty',
#   'illegal_aliens',
#   'labor',
#   'rights',
#   'union',
#   'workers',
#   'watch',
#   'repjimbanks',
#   'offers',
#   'amendment',
#   'prohibit',
#   'labor',
#   'organizations',
#   'encouraging',
#   'illegal',
#   'immigrants',
#   'joint',
#   'ranks'],
#  ['democrats',
#   'bill',
#   'would',
#   'disempower',
#   'american',
#   'workers',
#   'drowning',
#   'voices',
#   'benefit',
#   'illegal',
#   'immigrants'],
#  ['pic_twitter',
#   'com',
#   'kxqkyvf',
#   'ex',
#   'mark',
#   'bednar',
#   'markbednar',
#   'march',
#   'banks',
#   'said',
#   'bill',
#   'written',
#   'would',
#   'lessen',
#   'american',
#   'citizens',
#   'union',
#   'voting',
#   'power',
#   'hand',
#   'people',
#   'legally',
#   'employed',
#   'bill',
#   'would',
#   'disempower',
#   'american',
#   'workers',
#   'drowning',
#   'voices',
#   'benefit',
#   'illegal',
#   'immigrants',
#   'added',
#   'republican',
#   'amendment',
#   'reads',
#   'labor',
#   'union',
#   'shall',
#   'communicate',
#   'employee',
#   'regarding',
#   'joining',
#   'supporting',
#   'labor',
#   'organization',
#   'employee',
#   'authorized',
#   'work',
#   'united_states',
#   'democrats',
#   'defeated',
#   'amendment',
#   'democrats',
#   'banks',
#   'motion',
#   'gop',
#   'votes',
#   'favor',
#   'motion',
#   'recommit',
#   'tuesday',
#   'vote',
#   'serves',
#   'stark',
#   'contrast',
#   'last_year',
#   'motion',
#   'recommit',
#   'pro',
#   'act',
#   'considering',
#   'spanberger',
#   'voted',
#   'favor',
#   'republican',
#   'amendment',
#   'prevent',
#   'unions',
#   'encouraging',
#   'illegal_aliens',
#   'join',
#   'unions',
#   'sean',
#   'moran',
#   'congressional',
#   'reporter',
#   'breitbart_news'],
#  ['follow_twitter',
#   'seanmoran',
#   'economyimmigrationpoliticsabigail',
#   'spanbergerillegal',
#   'immigrantspro',
#   'actunions',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartpresident',
#   'joe_biden',
#   'administration',
#   'focused',
#   'educational',
#   'services',
#   'migrant',
#   'youth',
#   'arriving',
#   'united_states',
#   'mexico',
#   'border',
#   'even',
#   'millions',
#   'american',
#   'children',
#   'remain',
#   'shut',
#   'classroom',
#   'due',
#   'lockdowns',
#   'press',
#   'briefing',
#   'tuesday',
#   'white_house',
#   'press',
#   'secretary',
#   'jen',
#   'psaki',
#   'said',
#   'administration',
#   'working',
#   'ensure',
#   'unaccompanied',
#   'alien',
#   'children',
#   'uacs',
#   'arriving',
#   'southern',
#   'border',
#   'provided',
#   'educational',
#   'services',
#   'health',
#   'services',
#   'unaccompanied',
#   'children',
#   'come',
#   'across',
#   'border',
#   'want',
#   'keep',
#   'safe',
#   'want',
#   'ensure',
#   'shelters',
#   'access',
#   'educational',
#   'services',
#   'legal',
#   'services',
#   'health',
#   'services',
#   'psaki',
#   'said'],
#  ['want',
#   'ensure',
#   'quickly',
#   'moved',
#   'vetted',
#   'families',
#   'sponsor',
#   'homes',
#   'trying',
#   'close',
#   'borders',
#   'psaki',
#   'said',
#   'last_week',
#   'breitbart_news',
#   'reported',
#   'uacs',
#   'department',
#   'homeland',
#   'security',
#   'dhs',
#   'custody',
#   'eventually',
#   'transferred',
#   'department',
#   'health',
#   'human',
#   'services',
#   'hhs',
#   'received',
#   'variety',
#   'taxpayer',
#   'funded',
#   'services',
#   'simultaneously',
#   'potentially',
#   'millions',
#   'american',
#   'children',
#   'remain',
#   'shut',
#   'classroom',
#   'person',
#   'learning',
#   'teacher',
#   'unions',
#   'fight',
#   'keep',
#   'schools',
#   'closed',
#   'midst',
#   'chinese',
#   'coronavirus',
#   'crisis',
#   'los',
#   'angeles',
#   'county',
#   'california',
#   'instance',
#   'children',
#   'k',
#   'th',
#   'grade',
#   'set',
#   'locked',
#   'person',
#   'learning',
#   'year',
#   'new_york',
#   'times',
#   'reports',
#   'almost',
#   'year',
#   'since',
#   'coronavirus',
#   'pandemic',
#   'virtually',
#   'emptied',
#   'public',
#   'schools',
#   'los',
#   'angeles',
#   'sent',
#   'shamael',
#   'al',
#   'alim',
#   'home',
#   'take',
#   'classes',
#   'bedroom',
#   'miss',
#   'rising',
#   'catch',
#   'bus',
#   'train',
#   'high',
#   'school'],
#  ['much', 'miss', 'prospect', 'person', 'prom', 'graduation'],
#  ['history', 'teacher', 'ran', 'social', 'justice', 'club'],
#  ['pickup',
#   'basketball',
#   'gym',
#   'school',
#   'coach',
#   'made',
#   'everybody',
#   'feel',
#   'safe',
#   'real',
#   'senior',
#   'year',
#   'latest',
#   'data',
#   'compiled',
#   'education',
#   'week',
#   'breaks',
#   'state',
#   'state',
#   'school',
#   'closures',
#   'shows',
#   'still',
#   'six',
#   'states',
#   'florida',
#   'iowa',
#   'texas',
#   'arkansas',
#   'west_virginia',
#   'new',
#   'hampshire',
#   'require',
#   'person',
#   'learning'],
#  ['states',
#   'except',
#   'new',
#   'hampshire',
#   'require',
#   'schools',
#   'open',
#   'five',
#   'days',
#   'week',
#   'meanwhile',
#   'california',
#   'hawaii',
#   'delaware',
#   'washington',
#   'dc',
#   'continue',
#   'state',
#   'orders',
#   'place',
#   'kept',
#   'schools',
#   'partially',
#   'closed',
#   'person',
#   'learning'],
#  ['various',
#   'states',
#   'state',
#   'orders',
#   'localities',
#   'decide',
#   'whether',
#   'keep',
#   'schools',
#   'closed',
#   'report',
#   'october',
#   'revealed',
#   'three',
#   'million',
#   'american',
#   'children',
#   'went',
#   'without',
#   'education',
#   'last_year',
#   'statements',
#   'biden_administration',
#   'latest',
#   'draw',
#   'comparisons',
#   'restrictions',
#   'testing',
#   'quarantine',
#   'rules',
#   'american',
#   'citizens',
#   'versus',
#   'foreign',
#   'nationals',
#   'specifically',
#   'border_crossers',
#   'millions',
#   'americans',
#   'remain',
#   'lockdown',
#   'orders',
#   'number',
#   'states',
#   'biden_administration',
#   'releasing',
#   'thousands',
#   'border_crossers',
#   'u',
#   'interior',
#   'requirement',
#   'test',
#   'negative',
#   'coronavirus'],
#  ['even',
#   'border_crossers',
#   'test',
#   'positive',
#   'coronavirus',
#   'adhere',
#   'quarantine',
#   'standards',
#   'john',
#   'binder',
#   'reporter',
#   'breitbart_news'],
#  ['email', 'jbinder', 'breitbart', 'com'],
#  ['follow_twitter'],
#  ['educationimmigrationpoliticsjoe',
#   'bidenschooluacsunaccompanied',
#   'alien',
#   'children',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartthe',
#   'white_house',
#   'announced',
#   'return',
#   'portraits',
#   'former',
#   'presidents',
#   'bill',
#   'clinton',
#   'george',
#   'w',
#   'bush',
#   'foyer',
#   'monday',
#   'portraits',
#   'former',
#   'presidents',
#   'bill',
#   'clinton',
#   'george',
#   'w',
#   'bush',
#   'returned',
#   'traditional',
#   'locations',
#   'cross',
#   'hall',
#   'inauguration',
#   'day',
#   'office',
#   'curator',
#   'white_house',
#   'press',
#   'office',
#   'said',
#   'monday',
#   'july',
#   'former',
#   'president',
#   'trump',
#   'white_house',
#   'relocated',
#   'paintings',
#   'grand',
#   'foyer',
#   'old',
#   'family',
#   'dining',
#   'room',
#   'largely',
#   'used',
#   'store',
#   'tablecloths',
#   'furniture',
#   'recent',
#   'years'],
#  ['pictures',
#   'replaced',
#   'former',
#   'presidents',
#   'william',
#   'mckinley',
#   'successor',
#   'theodore',
#   'roosevelt',
#   'trump',
#   'invite',
#   'former',
#   'president',
#   'barack',
#   'obama',
#   'portrait',
#   'unveiling',
#   'president',
#   'joe_biden',
#   'yet',
#   'rule',
#   'former',
#   'guy',
#   'attendance',
#   'portrait',
#   'added',
#   'walls',
#   'portrait',
#   'revealings',
#   'portrait',
#   'plans',
#   'portrait',
#   'events',
#   'preview',
#   'given',
#   'indication',
#   'would',
#   'break',
#   'tradition',
#   'regard',
#   'white_house',
#   'press',
#   'secretary',
#   'jen',
#   'psaki',
#   'said',
#   'february',
#   'press',
#   'briefing',
#   'politicspre',
#   'viralbill',
#   'clintondonald',
#   'trumpgeorge',
#   'w',
#   'bushjoe',
#   'biden',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartsen'],
#  ['ted',
#   'cruz',
#   'r',
#   'tx',
#   'told',
#   'breitbart_news',
#   'sees',
#   'first',
#   'six',
#   'weeks',
#   'democrat',
#   'president',
#   'joe_biden',
#   'time',
#   'office',
#   'boring',
#   'radical',
#   'cruz',
#   'comments',
#   'came',
#   'lengthy',
#   'camera',
#   'nearly',
#   'minute',
#   'long',
#   'exclusive',
#   'interview',
#   'breitbart_news',
#   'thursday',
#   'morning',
#   'u',
#   'senate',
#   'office',
#   'washington',
#   'dc'],
#  ['interview',
#   'one',
#   'depth',
#   'ones',
#   'done',
#   'since',
#   'biden',
#   'took',
#   'white_house',
#   'democrats',
#   'swept',
#   'complete',
#   'control',
#   'washington',
#   'focused',
#   'early',
#   'days',
#   'biden',
#   'presidency',
#   'key',
#   'policy',
#   'issues',
#   'china',
#   'immigration',
#   'democrat',
#   'media',
#   'hypocrisy',
#   'demonstrated',
#   'handling',
#   'recent',
#   'trip',
#   'cancun'],
#  ['cruz',
#   'also',
#   'addressed',
#   'growing',
#   'concerns',
#   'many',
#   'republicans',
#   'texas',
#   'may',
#   'slipping',
#   'away',
#   'gop',
#   'grasp',
#   'explaining',
#   'new',
#   'trends',
#   'politics',
#   'working',
#   'class',
#   'voters',
#   'shifting',
#   'towards',
#   'republicans',
#   'suburban',
#   'women',
#   'moving',
#   'towards',
#   'democrats',
#   'cruz',
#   'interview',
#   'first',
#   'railed',
#   'biden',
#   'cabinet',
#   'nominees',
#   'though',
#   'disapproval',
#   'comes',
#   'little',
#   'surprise',
#   'one',
#   'dissenting',
#   'senators',
#   'confirmation',
#   'process',
#   'voting',
#   'cabinet',
#   'members',
#   'far',
#   'confirmed',
#   'reiterated',
#   'concerns',
#   'conveyed',
#   'hearings',
#   'grilled',
#   'ambassador',
#   'u',
#   'n',
#   'linda',
#   'thomas',
#   'greenfield',
#   'pro',
#   'china',
#   'speech',
#   'gave',
#   'confucius',
#   'institute',
#   'chastised',
#   'secretary',
#   'commerce',
#   'gina',
#   'raimondo',
#   'refusing',
#   'commit',
#   'keeping',
#   'chinese',
#   'companies',
#   'especially',
#   'huawei',
#   'describes',
#   'basically',
#   'espionage',
#   'agency',
#   'masquerades',
#   'telecom',
#   'company',
#   'u'],
#  ['entity',
#   'list',
#   'nominee',
#   'nominee',
#   'biden_administration',
#   'really',
#   'questionable',
#   'records',
#   'china',
#   'seems',
#   'part',
#   'pattern',
#   'deliberate',
#   'decision',
#   'pivot',
#   'back',
#   'towards',
#   'china',
#   'embrace',
#   'chinese',
#   'communist',
#   'government',
#   'said',
#   'cruz',
#   'saved',
#   'perhaps',
#   'harshest',
#   'words',
#   'xavier',
#   'becerra',
#   'attorney',
#   'general',
#   'california',
#   'biden',
#   'nominated',
#   'helm',
#   'department',
#   'health',
#   'human',
#   'services',
#   'hhs'],
#  ['cruz',
#   'pointed',
#   'soft',
#   'china',
#   'commentary',
#   'becerra',
#   'made',
#   'zoned',
#   'attorney',
#   'general',
#   'lack',
#   'experience',
#   'health',
#   'sector',
#   'middle',
#   'global',
#   'pandemic'],
#  ['joe_biden', 'likes', 'tell', 'us', 'daily', 'cruz', 'started'],
#  ['nominated',
#   'head',
#   'hhs',
#   'someone',
#   'medical',
#   'doctor',
#   'someone',
#   'healthcare',
#   'experience',
#   'whatsoever',
#   'someone',
#   'scientific',
#   'background',
#   'whatsoever',
#   'someone',
#   'experience',
#   'pharmaceuticals',
#   'experiences',
#   'virology',
#   'experiences',
#   'logistics'],
#  ['middle',
#   'largest',
#   'vaccine',
#   'deployment',
#   'american',
#   'history',
#   'becerra',
#   'know',
#   'thing',
#   'logistics',
#   'actually',
#   'moving',
#   'hundreds',
#   'millions',
#   'vaccines',
#   'across_country'],
#  ['trial', 'lawyer'],
#  ['zero', 'experience'],
#  ['republican',
#   'nominated',
#   'secretary',
#   'hhs',
#   'someone',
#   'medical',
#   'experience',
#   'scientific',
#   'experience',
#   'laughed',
#   'room'],
#  ['absurd'],
#  ['biden', 'nominate'],
#  ['becerra', 'leftist', 'partisan', 'radical'],
#  ['far',
#   'tell',
#   'experience',
#   'health',
#   'care',
#   'suing',
#   'little',
#   'sisters',
#   'poor',
#   'becerra',
#   'sued',
#   'trump',
#   'administration',
#   'granted',
#   'exemption',
#   'employers',
#   'want',
#   'provide',
#   'copay',
#   'free',
#   'insurance',
#   'coverage',
#   'contraception',
#   'grounds',
#   'religious',
#   'beliefs'],
#  ['lawsuit',
#   'inadvertently',
#   'targeted',
#   'catholic',
#   'nun',
#   'group',
#   'intervened',
#   'lawsuit',
#   'becerra',
#   'initiated'],
#  ['lawsuit',
#   'cruz',
#   'contends',
#   'health',
#   'related',
#   'bullet',
#   'point',
#   'becerra',
#   'resume',
#   'democrats',
#   'like',
#   'say',
#   'follow',
#   'science'],
#  ['listen',
#   'science',
#   'well',
#   'someone',
#   'lead',
#   'largest',
#   'cabinet',
#   'agency',
#   'domestically',
#   'knows',
#   'something',
#   'science'],
#  ['say',
#   'first',
#   'six',
#   'weeks',
#   'boring',
#   'radical',
#   'said',
#   'evidence',
#   'biden_administration',
#   'approach',
#   'coronavirus',
#   'lacks',
#   'authentic',
#   'concern',
#   'americans',
#   'health',
#   'cruz',
#   'said',
#   'lies',
#   'department',
#   'homeland',
#   'security',
#   'dhs',
#   'management',
#   'crossing',
#   'u',
#   'mexico',
#   'border'],
#  ['breitbart_news',
#   'reported',
#   'february',
#   'biden',
#   'dhs',
#   'requiring',
#   'border_crossers',
#   'undergo',
#   'coronavirus',
#   'testing',
#   'rules',
#   'cruz',
#   'said'],
#  ['testing'],
#  ['standards'],
#  ['willing', 'destroy', 'business'],
#  ['willing', 'destroy', 'job'],
#  ['willing', 'destroy', 'family'],
#  ['willing',
#   'tell',
#   'kids',
#   'go',
#   'school',
#   'comes',
#   'illegal',
#   'immigrants',
#   'releasing',
#   'testing',
#   'dhs',
#   'effectively',
#   'signaling',
#   'olly',
#   'olly',
#   'oxen',
#   'free',
#   'come',
#   'prospective',
#   'migrants',
#   'cruz',
#   'surmised',
#   'texas',
#   'republican',
#   'finds',
#   'coronavirus',
#   'serious',
#   'agrees',
#   'taking',
#   'sensible',
#   'precautions',
#   'last_week',
#   'gov'],
#  ['greg',
#   'abbott',
#   'lifted',
#   'texas',
#   'mask',
#   'mandate',
#   'increased',
#   'occupancy',
#   'capacity',
#   'businesses',
#   'percent',
#   'decision',
#   'cruz',
#   'applauded',
#   'announced',
#   'explained',
#   'breitbart_news',
#   'make',
#   'sense',
#   'shutting',
#   'businesses',
#   'shutting',
#   'schools',
#   'destroying',
#   'livelihoods',
#   'see',
#   'hypocrisy',
#   'left',
#   'example',
#   'democratic',
#   'governors',
#   'democratic',
#   'mayors',
#   'shutting',
#   'churches',
#   'protests',
#   'fine'],
#  ['leftist', 'protest', 'mask'],
#  ['screaming', 'someone', 'face', 'virus', 'transmitted'],
#  ['go',
#   'church',
#   'sing',
#   'hymn',
#   'clearly',
#   'threat',
#   'public',
#   'health',
#   'must',
#   'stopped',
#   'evident',
#   'anyone',
#   'looking',
#   'science'],
#  ['ideology'],
#  ['politics',
#   'said',
#   'cruz',
#   'also',
#   'said',
#   'biden_administration',
#   'found',
#   'ally',
#   'media',
#   'february',
#   'texas',
#   'experienced',
#   'catastrophic',
#   'winter',
#   'weather',
#   'resulted',
#   'mass',
#   'utility',
#   'outages',
#   'leading',
#   'biden_administration',
#   'declare',
#   'state',
#   'emergency',
#   'send',
#   'federal',
#   'aid',
#   'state',
#   'grappled',
#   'impacts'],
#  ['amid',
#   'disaster',
#   'cruz',
#   'spotted',
#   'boarding',
#   'plane',
#   'cancun',
#   'mexico',
#   'saw',
#   'democrats',
#   'media',
#   'lose',
#   'minds'],
#  ['stolen',
#   'nuclear',
#   'secrets',
#   'delivered',
#   'beijing',
#   'think',
#   'would',
#   'gotten',
#   'coverage',
#   'fact',
#   'took',
#   'kids',
#   'beach',
#   'cruz',
#   'observed',
#   'saying',
#   'regrets',
#   'decision',
#   'gave',
#   'ammunition',
#   'knuckleheads',
#   'tidal',
#   'wave',
#   'headlines',
#   'hit',
#   'internet',
#   'juxtaposing',
#   'tropical',
#   'trip',
#   'suffering',
#   'state',
#   'defenders',
#   'cruz',
#   'compared',
#   'coverage',
#   'cuomo'],
#  ['donald',
#   'trump',
#   'jr',
#   'notably',
#   'called',
#   'attention',
#   'fauxoutrage',
#   'accused',
#   'media',
#   'totally',
#   'silent',
#   'cuomo',
#   'nursing',
#   'home',
#   'scandal',
#   'came',
#   'head',
#   'february',
#   'aide',
#   'admitted',
#   'cuomo',
#   'administration',
#   'suppressed',
#   'data',
#   'number',
#   'coronavirus',
#   'related',
#   'deaths',
#   'occurred',
#   'new_york',
#   'nursing',
#   'homes',
#   'cruz',
#   'said',
#   'interesting',
#   'contrast',
#   'citing',
#   'recently',
#   'surfaced',
#   'sexual_assault',
#   'allegations',
#   'cuomo',
#   'along',
#   'staggeringly',
#   'stupid',
#   'nursing',
#   'home',
#   'policy'],
#  ['know', 'watching', 'andrew', 'cuomo', 'regime', 'crumble'],
#  ['really',
#   'striking',
#   'said',
#   'despite',
#   'biden',
#   'victory',
#   'former',
#   'president',
#   'donald',
#   'trump',
#   'november',
#   'cruz',
#   'assessed',
#   'america',
#   'remains',
#   'center',
#   'right',
#   'country',
#   'mainstream',
#   'media',
#   'entities',
#   'seeking',
#   'gaslight',
#   'american',
#   'people',
#   'beliefs',
#   'citing',
#   'conservative',
#   'position',
#   'low',
#   'taxes',
#   'low',
#   'regulation',
#   'job',
#   'abundance'],
#  ['press', 'hates', 'believe', 'said'],
#  ['trying', 'gaslight', 'us', 'trying', 'lie', 'us', 'cruz', 'added'],
#  ['trying',
#   'convince',
#   'conservative',
#   'home',
#   'one',
#   'write',
#   'ashley',
#   'oliver',
#   'aoliver',
#   'breitbart',
#   'com',
#   'healthmediapoliticsbiden',
#   'cabinetchinacoronavirusjoe',
#   'bidenon',
#   'hillted',
#   'cruz',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartnearly',
#   'million',
#   'americans',
#   'remain',
#   'unemployed',
#   'united_states',
#   'economy',
#   'though',
#   'want',
#   'full',
#   'time',
#   'jobs',
#   'president',
#   'joe_biden',
#   'administration',
#   'looks',
#   'pack',
#   'labor',
#   'market',
#   'foreign',
#   'workers',
#   'latest',
#   'bureau',
#   'labor',
#   'statistics',
#   'bls',
#   'data',
#   'february',
#   'finds',
#   'ten',
#   'million',
#   'americans',
#   'unemployed',
#   'million',
#   'labor',
#   'force',
#   'entirely',
#   'million',
#   'remain',
#   'underemployed',
#   'want',
#   'full',
#   'time',
#   'work',
#   'competitive',
#   'wages',
#   'good',
#   'benefits',
#   'ten',
#   'million',
#   'americans',
#   'unemployed',
#   'million',
#   'jobless',
#   'weeks'],
#  ['nearly',
#   'percent',
#   'counted',
#   'unemployed',
#   'bls',
#   'teenagers',
#   'percent',
#   'black',
#   'americans',
#   'percent',
#   'hispanic',
#   'million',
#   'white',
#   'americans',
#   'economy',
#   'reopens',
#   'federal',
#   'enhancements',
#   'unemployment',
#   'insurance',
#   'could',
#   'create',
#   'temporary',
#   'labor',
#   'shortages',
#   'potential',
#   'workers',
#   'get',
#   'benefits',
#   'would',
#   'earn',
#   'wages',
#   'jobless',
#   'data',
#   'though',
#   'reveals',
#   'extent',
#   'claims',
#   'shortage',
#   'labor',
#   'widely',
#   'oversold',
#   'big',
#   'business',
#   'corporate',
#   'interests',
#   'consistently',
#   'asked',
#   'increases',
#   'legal',
#   'immigration',
#   'levels',
#   'biden_administration',
#   'despite',
#   'facing',
#   'continued',
#   'unemployment',
#   'crisis',
#   'sought',
#   'increase',
#   'overall',
#   'immigration',
#   'levels',
#   'u',
#   'pack',
#   'labor',
#   'market',
#   'foreign',
#   'workers'],
#  ['recent',
#   'move',
#   'biden',
#   'lifted',
#   'trump',
#   'era',
#   'executive',
#   'order',
#   'slowed',
#   'certain',
#   'green',
#   'card',
#   'categories',
#   'decrease',
#   'foreign',
#   'competition',
#   'labor',
#   'market',
#   'likewise',
#   'biden_administration',
#   'released',
#   'u',
#   'thousand',
#   'migrants',
#   'enrolled',
#   'defunct',
#   'remain',
#   'mexico',
#   'program',
#   'two',
#   'weeks'],
#  ['adults',
#   'able',
#   'apply',
#   'work',
#   'permits',
#   'take',
#   'jobs',
#   'economy',
#   'already',
#   'current',
#   'immigration',
#   'levels',
#   'put',
#   'downward',
#   'pressure',
#   'u',
#   'wages',
#   'redistributing',
#   'billion',
#   'wealth',
#   'away',
#   'america',
#   'working',
#   'middle',
#   'class',
#   'towards',
#   'employers',
#   'new',
#   'arrivals',
#   'research',
#   'national',
#   'academies',
#   'sciences',
#   'engineering',
#   'medicine',
#   'found',
#   'similarly',
#   'peer',
#   'reviewed',
#   'research',
#   'economist',
#   'christoph',
#   'albert',
#   'acknowledges',
#   'immigrants',
#   'accept',
#   'lower',
#   'wages',
#   'preferably',
#   'chosen',
#   'firms',
#   'therefore',
#   'higher',
#   'job',
#   'finding',
#   'rates',
#   'natives',
#   'consistent',
#   'evidence',
#   'found',
#   'u',
#   'data',
#   'albert',
#   'research',
#   'also',
#   'finds',
#   'immigration',
#   'raises',
#   'competition',
#   'native',
#   'born',
#   'americans',
#   'labor',
#   'market',
#   'americans',
#   'overwhelmingly',
#   'support',
#   'decreasing',
#   'overall',
#   'immigration',
#   'u',
#   'recent',
#   'surveys',
#   'found'],
#  ['latest',
#   'rasmussen',
#   'reports',
#   'survey',
#   'showed',
#   'nearly',
#   'seven',
#   'ten',
#   'likely',
#   'voters',
#   'support',
#   'mandatory',
#   'e',
#   'verify',
#   'ban',
#   'illegal',
#   'hiring',
#   'percent',
#   'support',
#   'reducing',
#   'legal',
#   'immigration',
#   'levels',
#   'percent',
#   'said',
#   'businesses',
#   'recruit',
#   'americans',
#   'jobs',
#   'rather',
#   'importing',
#   'foreign',
#   'workers',
#   'john',
#   'binder',
#   'reporter',
#   'breitbart_news'],
#  ['email', 'jbinder', 'breitbart', 'com'],
#  ['follow_twitter'],
#  ['economyimmigrationpoliticscoronavirusforeign',
#   'workersjoblessjobslabor',
#   'marketunemploymentwages',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartrep'],
#  ['vicente',
#   'gonzalez',
#   'tx',
#   'closed',
#   'account',
#   'bank_china',
#   'following',
#   'breitbart_news',
#   'report',
#   'texas',
#   'democrat',
#   'holdings',
#   'state',
#   'owned',
#   'institution',
#   'gonzalez',
#   'recent',
#   'financial',
#   'disclosure',
#   'forms',
#   'list',
#   'holdings',
#   'worth',
#   'bank_china',
#   'state',
#   'owned',
#   'organ',
#   'chinese',
#   'communist',
#   'party',
#   'ccp',
#   'breitbart_news',
#   'reported',
#   'second',
#   'page',
#   'calendar',
#   'year',
#   'disclosure',
#   'documents',
#   'gonzalez',
#   'reported',
#   'holdings',
#   'valued',
#   'bank_china'],
#  ['report',
#   'includes',
#   'disclosure',
#   'gonzalez',
#   'earned',
#   'interest',
#   'year',
#   'bank_china',
#   'account',
#   'bank_china',
#   'website',
#   'acknowledges',
#   'wholly',
#   'state',
#   'owned',
#   'commercial',
#   'bank',
#   'since',
#   'mid'],
#  ['state',
#   'run',
#   'enterprise',
#   'also',
#   'pledges',
#   'allegiance',
#   'chinese',
#   'head',
#   'state',
#   'xi',
#   'jinping',
#   'communist',
#   'ideology',
#   'describing',
#   'mission',
#   'furtherance',
#   'ccp',
#   'global',
#   'political',
#   'vision',
#   'gonzalez',
#   'closed',
#   'account',
#   'following',
#   'breitbart_news',
#   'report',
#   'according',
#   'news',
#   'antonio',
#   'nbc',
#   'affiliate'],
#  ['also',
#   'rejected',
#   'interview',
#   'request',
#   'congressman',
#   'texas',
#   'earned',
#   'thousands',
#   'interest',
#   'bank_china',
#   'https',
#   'co',
#   'z',
#   'cxwoxqb',
#   'pic_twitter',
#   'com',
#   'pcqnz',
#   'qvbg',
#   'news',
#   'san',
#   'antonio',
#   'news',
#   'sa',
#   'march',
#   'news',
#   'san',
#   'antonio',
#   'reported',
#   'gonzalez',
#   'press',
#   'secretary',
#   'jason',
#   'johnson',
#   'told',
#   'news',
#   'san',
#   'antonio',
#   'bank_china',
#   'insured',
#   'operating',
#   'u',
#   'laws'],
#  ['johnson',
#   'also',
#   'told',
#   'news',
#   'san',
#   'antonio',
#   'congressman',
#   'closed',
#   'account',
#   'monica',
#   'de',
#   'la',
#   'cruz',
#   'hernandez',
#   'gonzalez',
#   'republican',
#   'opponent',
#   'remarked',
#   'recent',
#   'exposure',
#   'gonzalez',
#   'financial',
#   'ties',
#   'china'],
#  ['gonzalez',
#   'six',
#   'figure',
#   'account',
#   'bank_china',
#   'shocking',
#   'disturbing'],
#  ['us',
#   'rep',
#   'never',
#   'close',
#   'financial',
#   'ties',
#   'state',
#   'bank',
#   'country',
#   'greatest',
#   'adversary'],
#  ['america', 'first', 'china'],
#  ['https',
#   'co',
#   'x',
#   'seycppbh',
#   'monica',
#   'de',
#   'la',
#   'cruz',
#   'hernandez',
#   'congress',
#   'monica',
#   'congress',
#   'march',
#   'de',
#   'la',
#   'cruz',
#   'hernandez',
#   'tweeted',
#   'gonzalez',
#   'six',
#   'figure',
#   'account',
#   'bank_china',
#   'shocking',
#   'disturbing'],
#  ['us',
#   'rep',
#   'never',
#   'close',
#   'financial',
#   'ties',
#   'state',
#   'bank',
#   'country',
#   'greatest',
#   'adversary'],
#  ['america', 'first', 'china'],
#  ['national',
#   'securitypoliticsbank',
#   'chinabreitbart',
#   'texaschinachinese',
#   'communist',
#   'party',
#   'ccp',
#   'monica',
#   'de',
#   'la',
#   'cruz',
#   'hernandeztexasvicente',
#   'gonzalezxi',
#   'jinping',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartdistrict',
#   'attorneys',
#   'larry',
#   'krasner',
#   'philadelphia',
#   'pennsylvania',
#   'kimberly',
#   'foxx',
#   'cook',
#   'county',
#   'illinois',
#   'diana',
#   'becton',
#   'contra',
#   'costa',
#   'county',
#   'california',
#   'taken',
#   'campaign',
#   'donations',
#   'billionaire',
#   'george',
#   'soros',
#   'helping',
#   'criminal',
#   'illegal_aliens',
#   'avoid',
#   'deportation',
#   'united_states',
#   'investigation',
#   'reveals',
#   'immigration',
#   'reform',
#   'law',
#   'institute',
#   'irli',
#   'sheds',
#   'light',
#   'new',
#   'avenues',
#   'district',
#   'attorneys',
#   'use',
#   'offices',
#   'aid',
#   'criminally',
#   'charged',
#   'illegal_aliens',
#   'specifically',
#   'getting',
#   'hook',
#   'arrested',
#   'immigration',
#   'customs',
#   'enforcement',
#   'ice',
#   'deported',
#   'krasner',
#   'investigation',
#   'found',
#   'raked',
#   'nearly',
#   'million',
#   'soros',
#   'linked',
#   'group',
#   'philadelphia',
#   'justice',
#   'public',
#   'safety',
#   'pac'],
#  ['elected',
#   'krasner',
#   'created',
#   'immigration',
#   'counsel',
#   'district',
#   'attorney',
#   'office',
#   'hiring',
#   'former',
#   'immigration',
#   'attorney',
#   'caleb',
#   'arnold',
#   'lead',
#   'initiative'],
#  ['goal',
#   'initiative',
#   'reduce',
#   'immigration',
#   'consequences',
#   'defendants',
#   'result',
#   'irli',
#   'investigation',
#   'notes',
#   'arnold',
#   'consulted',
#   'cases',
#   'defendant',
#   'foreign',
#   'national'],
#  ['cases',
#   'outcomes',
#   'changed',
#   'plea',
#   'agreements',
#   'many',
#   'defendants',
#   'arnold',
#   'consulted',
#   'help',
#   'avoid',
#   'deportation',
#   'charged',
#   'murder',
#   'rape',
#   'forcible',
#   'rape',
#   'rape',
#   'child',
#   'sexual_assault',
#   'unlawful',
#   'contact',
#   'minor',
#   'attempted',
#   'murder',
#   'drunk',
#   'driving',
#   'robbery',
#   'crimes',
#   'krasner',
#   'immigration',
#   'counsel',
#   'paid',
#   'nearly',
#   'january',
#   'november',
#   'arnold',
#   'remains',
#   'sole',
#   'employee',
#   'initiative',
#   'irli',
#   'executive',
#   'director',
#   'dale',
#   'wilcox',
#   'said_statement',
#   'outrageous',
#   'examples',
#   'elections',
#   'manipulated',
#   'wealthy',
#   'donors',
#   'extreme',
#   'anti',
#   'borders',
#   'agendas'],
#  ['district',
#   'attorneys',
#   'claim',
#   'trying',
#   'bring',
#   'justice',
#   'legal',
#   'system',
#   'actually',
#   'putting',
#   'residents',
#   'communities',
#   'great',
#   'risk',
#   'allowing',
#   'violent',
#   'criminals',
#   'escape',
#   'deportation',
#   'likewise',
#   'cook',
#   'county',
#   'district',
#   'attorney',
#   'kimberly',
#   'foxx',
#   'benefited',
#   'campaign',
#   'donations',
#   'soros',
#   'linked',
#   'illinois',
#   'safety',
#   'justice',
#   'pac'],
#  ['taking',
#   'office',
#   'foxx',
#   'hired',
#   'michael',
#   'kasprzynski',
#   'office',
#   'first',
#   'immigration',
#   'adviser',
#   'kasprzynski',
#   'role',
#   'described',
#   'working',
#   'ensure',
#   'noncitizen',
#   'defendants',
#   'face',
#   'unnecessary',
#   'immigration',
#   'consequences',
#   'particularly',
#   'misdemeanor',
#   'low',
#   'level',
#   'offenses',
#   'role',
#   'effectively',
#   'seeks',
#   'help',
#   'criminally',
#   'charged',
#   'illegal_aliens',
#   'escape',
#   'arrest',
#   'ice',
#   'deportation',
#   'contra',
#   'costa',
#   'county',
#   'district',
#   'attorney',
#   'diana',
#   'becton',
#   'also',
#   'supported',
#   'indirectly',
#   'soros',
#   'campaign',
#   'donations',
#   'via',
#   'million',
#   'contribution',
#   'california',
#   'justice',
#   'public',
#   'safety',
#   'pac',
#   'taking',
#   'office',
#   'becton',
#   'issued',
#   'immigration',
#   'policy',
#   'memo',
#   'states',
#   'prosecutors',
#   'contra',
#   'costa',
#   'county',
#   'district',
#   'attorney',
#   'office',
#   'shall',
#   'consider',
#   'avoidance',
#   'adverse',
#   'immigration',
#   'consequences',
#   'plea',
#   'negotiation',
#   'process',
#   'becton',
#   'previously',
#   'said',
#   'office',
#   'takes',
#   'consideration',
#   'foreign',
#   'national',
#   'immigration',
#   'status',
#   'help',
#   'reduce',
#   'risk',
#   'defendant',
#   'arrested',
#   'ice',
#   'deported',
#   'john',
#   'binder',
#   'reporter',
#   'breitbart_news'],
#  ['email', 'jbinder', 'breitbart', 'com'],
#  ['follow_twitter'],
#  ['crimeimmigrationpoliticscaliforniacook',
#   'countygeorge',
#   'sorosillegal',
#   'immigrationillinoiskim',
#   'foxxpennsylvaniaphiladelphia',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartlos',
#   'angeles',
#   'california',
#   'california',
#   'governor',
#   'gavin',
#   'newsom',
#   'delivered',
#   'annual',
#   'state',
#   'state',
#   'address',
#   'empty',
#   'dodger',
#   'stadium',
#   'tuesday',
#   'night',
#   'hoping',
#   'rally',
#   'support',
#   'faces',
#   'likely',
#   'recall',
#   'election',
#   'coming',
#   'months',
#   'newsom',
#   'struck',
#   'optimistic',
#   'tone',
#   'noting',
#   'state',
#   'coronavirus',
#   'numbers',
#   'improving'],
#  ['admitted', 'errors', 'made', 'mistakes', 'said'],
#  ['made', 'mistakes'],
#  [],
#  ['learn'],
#  ['never',
#   'stop',
#   'trying',
#   'state',
#   'state',
#   'said',
#   'remains',
#   'determined',
#   'mean',
#   'determined',
#   'took',
#   'swipe',
#   'critics',
#   'saying',
#   'motivated',
#   'partisan',
#   'agendas',
#   'outdated',
#   'prejudices',
#   'rejecting',
#   'everything',
#   'makes',
#   'california',
#   'truly',
#   'great',
#   'decision',
#   'deliver',
#   'address',
#   'remotely',
#   'tribute',
#   'world',
#   'series',
#   'champions',
#   'well',
#   'californians',
#   'died',
#   'covid',
#   'medical',
#   'staff',
#   'turned',
#   'stadium',
#   'vaccination',
#   'site',
#   'added',
#   'california',
#   'going',
#   'come',
#   'crawling',
#   'back',
#   'roar',
#   'back',
#   'newsom',
#   'also',
#   'appealed',
#   'supporters',
#   'left',
#   'saying',
#   'pandemic',
#   'going',
#   'go',
#   'back',
#   'normal'],
#  ['think',
#   'agree',
#   'normal',
#   'never',
#   'good',
#   'enough',
#   'path',
#   'back',
#   'said',
#   'must',
#   'also',
#   'path',
#   'close',
#   'economic',
#   'inequities',
#   'unacceptable',
#   'disparities',
#   'added',
#   'economic',
#   'recovery',
#   'economic',
#   'recovery',
#   'without',
#   'economic',
#   'justice',
#   'live',
#   'governor',
#   'gavinnewsom',
#   'reflect',
#   'california',
#   'journey',
#   'pandemic',
#   'towards',
#   'brighter',
#   'future',
#   'state',
#   'state',
#   'address',
#   'dodgers',
#   'stadium'],
#  ['https',
#   'co',
#   'umbrejpw',
#   'office',
#   'governor',
#   'california',
#   'cagovernor',
#   'march',
#   'newsom',
#   'also',
#   'noted',
#   'despite',
#   'ongoing',
#   'economic',
#   'shutdowns',
#   'state',
#   'billion',
#   'surplus',
#   'start',
#   'revenues',
#   'continued',
#   'grow',
#   'thanks',
#   'silicon',
#   'valley',
#   'profits',
#   'wall',
#   'street',
#   'stocks',
#   'could',
#   'added',
#   'touted',
#   'state',
#   'ongoing',
#   'vaccination',
#   'effort',
#   'one',
#   'time',
#   'slowest',
#   'nation',
#   'boasting',
#   'built',
#   'around',
#   'equity',
#   'setting',
#   'aside',
#   'percentage',
#   'doses',
#   'minority',
#   'communities',
#   'heavily',
#   'impacted',
#   'covid'],
#  ['also',
#   'promised',
#   'least',
#   'percent',
#   'vaccine',
#   'allocations',
#   'go',
#   'directly',
#   'teachers',
#   'school',
#   'staff',
#   'promised',
#   'schools',
#   'would',
#   'reopen',
#   'soon',
#   'major',
#   'point',
#   'contention',
#   'teachers',
#   'unions',
#   'l',
#   'san',
#   'francisco',
#   'newsom',
#   'also',
#   'spoke',
#   'state',
#   'efforts',
#   'fight',
#   'wildfires',
#   'homelessness',
#   'proudly',
#   'reiterated',
#   'state',
#   'goal',
#   'make',
#   'new',
#   'cars',
#   'california',
#   'roads',
#   'zero',
#   'emissions',
#   'help',
#   'assist',
#   'fight',
#   'global',
#   'climate',
#   'change',
#   'moment',
#   'create',
#   'california',
#   'want',
#   'live',
#   'extend',
#   'dream',
#   'prosperity',
#   'equity',
#   'progress',
#   'continue',
#   'lead',
#   'world',
#   'future',
#   'newsom',
#   'concluded',
#   'newsom',
#   'spoke',
#   'hours',
#   'opponents',
#   'announced',
#   'gathered',
#   'nearly',
#   'million',
#   'signatures',
#   'nearly',
#   'necessary',
#   'force',
#   'recall',
#   'election'],
#  ['state',
#   'voters',
#   'asked',
#   'whether',
#   'retain',
#   'replace',
#   'newsom',
#   'governor',
#   'one',
#   'potential',
#   'replacements',
#   'republican',
#   'former',
#   'mayor',
#   'san',
#   'diego',
#   'kevin',
#   'faulconer',
#   'tweeted',
#   'response',
#   'newsom',
#   'response',
#   'gavin',
#   'newsom',
#   'state',
#   'state',
#   'address'],
#  ['pic_twitter',
#   'com',
#   'cbsruhe',
#   'gw',
#   'kevin',
#   'faulconer',
#   'kevin',
#   'faulconer',
#   'march',
#   'crisis',
#   'exceeds',
#   'current',
#   'governor',
#   'ability',
#   'deal',
#   'faulconer',
#   'said',
#   'saying',
#   'newsom',
#   'focused',
#   'saving',
#   'political',
#   'career',
#   'state',
#   'needs'],
#  ['governor',
#   'lead',
#   'california',
#   'comeback',
#   'state',
#   'needs',
#   'joel',
#   'b',
#   'pollak',
#   'senior',
#   'editor',
#   'large',
#   'breitbart_news',
#   'host',
#   'breitbart_news',
#   'sunday',
#   'sirius',
#   'xm',
#   'patriot',
#   'sunday',
#   'evenings',
#   'p',
#   'p'],
#  ['et', 'p', 'p', 'pt'],
#  ['newest',
#   'e',
#   'book',
#   'sh',
#   'thole',
#   'country',
#   'lessons',
#   'south',
#   'africa'],
#  ['recent',
#   'book',
#   'red',
#   'november',
#   'tells',
#   'story',
#   'democratic',
#   'presidential',
#   'primary',
#   'conservative',
#   'perspective'],
#  ['winner', 'robert', 'novak', 'journalism', 'alumni', 'fellowship'],
#  ['follow_twitter',
#   'joelpollak',
#   'economyhealthpoliticscaliforniacalifornia',
#   'recallgavin',
#   'newsomstate',
#   'state',
#   'please_let',
#   'us_know',
#   'issues_commenting',
#   'copyright',
#   'breitbartbut',
#   'yet',
#   'infection',
#   'numbers',
#   'weeks',
#   'declines',
#   'seem',
#   'plateaued',
#   'high',
#   'levels'],
#  ['us', 'averaged', 'covid', 'cases', 'daily', 'past', 'week'],
#  ['people',
#   'remain',
#   'hospitalized',
#   'virus',
#   'nationwide',
#   'according',
#   'covid',
#   'tracking',
#   'project'],
#  ['average',
#   'us',
#   'covid',
#   'deaths',
#   'reported',
#   'every',
#   'day',
#   'past',
#   'seven',
#   'days',
#   'highly',
#   'contagious',
#   'variants',
#   'already',
#   'circulating',
#   'experts',
#   'worried',
#   'another',
#   'covid',
#   'spike',
#   'could',
#   'weeks',
#   'away'],
#  ['cases',
#   'variants',
#   'first',
#   'spotted',
#   'uk',
#   'south',
#   'africa',
#   'brazil',
#   'reported',
#   'us',
#   'according',
#   'centers',
#   'disease',
#   'control',
#   'prevention',
#   'agency',
#   'cautioned',
#   'total',
#   'number',
#   'cases',
#   'country',
#   'rather',
#   'spotted',
#   'help',
#   'genomic',
#   'sequencing'],
#  ['vast',
#   'majority',
#   'cases',
#   'least',
#   'contagious',
#   'variant',
#   'known',
#   'b',
#   'first',
#   'spotted',
#   'uk'],
#  ['variant', 'found', 'states', 'puerto', 'rico', 'washington', 'dc'],
#  ['strain',
#   'increasing',
#   'exponentially',
#   'spiking',
#   'infectious',
#   'diseases',
#   'specialist',
#   'epidemiologist',
#   'dr',
#   'celine',
#   'gounder',
#   'told',
#   'cnn',
#   'saturday'],
#  ['probably', 'right', 'tipping', 'point', 'another', 'surge'],
#  ['speaking',
#   'dangers',
#   'variant',
#   'michael',
#   'osterholm',
#   'director',
#   'center',
#   'infectious',
#   'disease',
#   'research',
#   'policy',
#   'university',
#   'minnesota',
#   'warned',
#   'cnn',
#   'friday',
#   'virus',
#   'take',
#   'united_states'],
#  ['variants',
#   'big',
#   'reason',
#   'experts',
#   'repeatedly',
#   'warned',
#   'time',
#   'double',
#   'measures',
#   'work',
#   'curb',
#   'spread',
#   'virus',
#   'ease',
#   'covid',
#   'restrictions'],
#  ['many',
#   'reasons',
#   'want',
#   'pull',
#   'back',
#   'dr',
#   'anthony',
#   'fauci',
#   'told',
#   'cnn',
#   'late',
#   'last_week'],
#  ['want', 'plan', 'able', 'within', 'reasonable', 'time', 'pull', 'back'],
#  ['time',
#   'circulating',
#   'variants',
#   'looks',
#   'like',
#   'plateauing',
#   'decline',
#   'cases'],
#  ['states',
#   'announced',
#   'loosened',
#   'restrictions',
#   'last',
#   'weekdespite',
#   'health',
#   'leaders',
#   'warnings',
#   'several',
#   'state',
#   'leaders',
#   'announced',
#   'easing',
#   'covid',
#   'restrictions'],
#  ['texas', 'gov'],
#  ['greg',
#   'abbott',
#   'announced',
#   'tuesday',
#   'lifting',
#   'statewide',
#   'mask',
#   'mandate',
#   'away',
#   'capacity',
#   'limits',
#   'businesses',
#   'beginning',
#   'march'],
#  ['time', 'open', 'texas', 'said', 'day', 'mississippi', 'gov'],
#  ['tate',
#   'reeves',
#   'said',
#   'lifting',
#   'county',
#   'mask',
#   'mandates',
#   'would',
#   'allow',
#   'businesses',
#   'operate',
#   'full',
#   'capacity',
#   'without',
#   'state',
#   'imposed',
#   'rules'],
#  ['ohio', 'gov'],
#  ['mike',
#   'dewine',
#   'announced',
#   'revisions',
#   'public',
#   'health',
#   'orders',
#   'tuesday',
#   'including',
#   'dropping',
#   'person',
#   'limit',
#   'events',
#   'banquet',
#   'centers'],
#  ['thursday',
#   'said',
#   'state',
#   'reaches',
#   'cases',
#   'per',
#   'people',
#   'two',
#   'weeks',
#   'health',
#   'orders',
#   'lifted'],
#  ['meanwhile', 'michigan', 'gov'],
#  ['gretchen',
#   'whitmer',
#   'unveiled',
#   'series',
#   'eased',
#   'restrictions',
#   'including',
#   'expanded',
#   'capacity',
#   'restaurants',
#   'retail',
#   'gyms',
#   'stadiums',
#   'facilities',
#   'louisiana',
#   'gov'],
#  ['john', 'bel', 'edwards', 'also', 'loosened', 'restrictions'],
#  ['majority',
#   'businesses',
#   'including',
#   'restaurants',
#   'salons',
#   'allowed',
#   'operate',
#   'capacity',
#   'religious',
#   'services',
#   'longer',
#   'capacity',
#   'limits',
#   'friday',
#   'arizona',
#   'gov'],
#  ['doug',
#   'ducey',
#   'also',
#   'said',
#   'lifting',
#   'occupancy',
#   'limits',
#   'businesses',
#   'including',
#   'restaurants',
#   'gyms',
#   'theaters'],
#  ['similar', 'announcement', 'came', 'west_virginia', 'gov'],
#  ['jim',
#   'justice',
#   'said',
#   'restaurants',
#   'bars',
#   'businesses',
#   'including',
#   'gyms',
#   'museums',
#   'could',
#   'begin',
#   'operate',
#   'capacity'],
#  ['justice', 'also', 'upped', 'social', 'gathering', 'limit', 'people'],
#  ['south', 'carolina', 'gov'],
#  ['henry',
#   'mcmaster',
#   'issued',
#   'executive',
#   'order',
#   'friday',
#   'rescinding',
#   'face',
#   'covering',
#   'requirements',
#   'state',
#   'government',
#   'offices',
#   'buildings',
#   'facilities',
#   'well',
#   'restaurants'],
#  ['meanwhile',
#   'california',
#   'state',
#   'amusement',
#   'parks',
#   'including',
#   'disneyland',
#   'magic',
#   'mountain',
#   'universal',
#   'studios',
#   'along',
#   'sports',
#   'concert',
#   'venues',
#   'allowed',
#   'reopen',
#   'limited',
#   'capacity',
#   'starting',
#   'april',
#   'health',
#   'human',
#   'services',
#   'secretary',
#   'mark',
#   'ghaly',
#   'announced',
#   'friday'],
#  ['feel',
#   'like',
#   'appropriate',
#   'time',
#   'begin',
#   'reintroduce',
#   'activities',
#   'fashion',
#   'guarded',
#   'way',
#   'slow',
#   'steady',
#   'way',
#   'ghaly',
#   'said'],
#  ['many',
#   'americans',
#   'vaccinatedin',
#   'announcements',
#   'eased',
#   'restrictions',
#   'several',
#   'state',
#   'leaders',
#   'pointed',
#   'growing',
#   'light',
#   'end',
#   'tunnel',
#   'expressed',
#   'optimism',
#   'fueled',
#   'growing',
#   'vaccination',
#   'numbers'],
#  ['experts',
#   'cautioned',
#   'us',
#   'likely',
#   'still',
#   'months',
#   'go',
#   'enough',
#   'americans',
#   'vaccinated',
#   'help',
#   'suppress',
#   'spread',
#   'virus'],
#  ['far',
#   'less',
#   'country',
#   'population',
#   'fully',
#   'vaccinated',
#   'us',
#   'could',
#   'reach',
#   'herd',
#   'immunity',
#   'vaccinations',
#   'alonemore',
#   'million',
#   'americans',
#   'received',
#   'least',
#   'first',
#   'dose',
#   'covid',
#   'vaccine',
#   'cdc',
#   'data',
#   'shows'],
#  ['million', 'received', 'two', 'doses', 'vaccine', 'according', 'data'],
#  ['roughly',
#   'us',
#   'population',
#   'country',
#   'vaccination',
#   'effort',
#   'many',
#   'ways',
#   'race',
#   'time',
#   'experts',
#   'said',
#   'state',
#   'officials',
#   'work',
#   'get',
#   'many',
#   'shots',
#   'arms',
#   'possible',
#   'dangerous',
#   'variants',
#   'potentially',
#   'take'],
#  ['last_week',
#   'new',
#   'research',
#   'offered',
#   'reassuring',
#   'news',
#   'evidence',
#   'b',
#   'variant',
#   'poses',
#   'little',
#   'threat',
#   'efficacy',
#   'vaccines'],
#  ['research',
#   'published',
#   'thursday',
#   'shows',
#   'variant',
#   'hide',
#   'little',
#   'bit',
#   'immune',
#   'system',
#   'enough',
#   'decrease',
#   'value',
#   'vaccines',
#   'significantly',
#   'threaten',
#   'reinfect',
#   'people',
#   'recovered',
#   'previous',
#   'dominant',
#   'variant',
#   'virus'],
#  ['findings',
#   'indicate',
#   'variant',
#   'b',
#   'unlikely',
#   'major',
#   'concern',
#   'current',
#   'vaccines',
#   'increased',
#   'risk',
#   'reinfection',
#   'researchers',
#   'wrote',
#   'report',
#   'published',
#   'journal',
#   'cell',
#   'host',
#   'microbe',
#   'receiving',
#   'doses',
#   'timely',
#   'manner',
#   'encouraged',
#   'maximum',
#   'efficacy',
#   'areas',
#   'variant',
#   'circulating',
#   'researchers',
#   'said'],
#  ['want', 'inspiring', 'positive', 'news'],
#  ['sign', 'good', 'stuff', 'newsletter', 'good', 'life'],
#  ['brighten', 'inbox', 'every', 'saturday', 'morning'],
#  ['one', 'new', 'jersey', 'man', 'rescue', 'dog', 'become', 'much'],
#  ['sadie',
#   'pound',
#   'german',
#   'shepherd',
#   'turned',
#   'away',
#   'three',
#   'shelters',
#   'time',
#   'arrived',
#   'ramapo',
#   'bergen',
#   'animal',
#   'refuge',
#   'oakland',
#   'new',
#   'jersey',
#   'early'],
#  ['sadie', 'anxious', 'especially', 'uneasy', 'around', 'men'],
#  ['shelter',
#   'kind',
#   'last',
#   'resort',
#   'place',
#   'unwanted',
#   'dogs',
#   'rbari',
#   'executive',
#   'director',
#   'megan',
#   'brinster',
#   'told',
#   'cnn'],
#  ['gotten', 'really', 'good', 'finding', 'homes', 'kinds', 'dogs'],
# ...
#  ['woman',
#   'also',
#   'arrested',
#   'location',
#   'suspicion',
#   'assisting',
#   'offender',
#   'arrest',
#   'evening',
#   'serious',
#   'significant',
#   'development',
#   'assistant',
#   'commissioner',
#   'nick',
#   'ephgrave',
#   'said_statement',
#   'continue',
#   'work',
#   'speed',
#   'investigation',
#   'fact',
#   'arrested',
#   'man',
#   'serving',
#   'metropolitan',
#   'police_officer',
#   'shocking',
#   'deeply',
#   'disturbing',
#   'police',
#   'launched',
#   'extensive',
#   'investigation',
#   'find',
#   'everard',
#   'officers',
#   'searching',
#   'streets',
#   'nearby',
#   'areas',
#   'route',
#   'home',
#   'went',
#   'near',
#   'large',
#   'grassy',
#   'clapham',
#   'common',
#   'area',
#   'police',
#   'family',
#   'released',
#   'number',
#   'photos',
#   'woman',
#   'taken',
#   'evening',
#   'cctv',
#   'cameras',
#   'previous',
#   'occasions',
#   'hope',
#   'someone',
#   'remember',
#   'seeing',
#   'searching',
#   'hard',
#   'find',
#   'sarah',
#   'really',
#   'hope',
#   'case',
#   'ephgrave',
#   'said',
#   'asked',
#   'reporters',
#   'still',
#   'alive',
#   'wednesday',
#   'said',
#   'could',
#   'give',
#   'details',
#   'whether',
#   'pair',
#   'knew',
#   'long',
#   'man',
#   'police_officer',
#   'organisation',
#   'charged',
#   'policing',
#   'conduct',
#   'officers',
#   'aware',
#   'arrest',
#   'brussels',
#   'reuters',
#   'european',
#   'union',
#   'responded',
#   'wednesday',
#   'summons',
#   'britain',
#   'dispute',
#   'accusations',
#   'vaccine',
#   'nationalism',
#   'latest',
#   'series',
#   'skirmishes',
#   'bloc',
#   'former',
#   'member',
#   'since',
#   'left',
#   'eu',
#   'eu',
#   'would',
#   'send',
#   'charge',
#   'affaires',
#   'nicole',
#   'mannion',
#   'effectively',
#   'eu',
#   'deputy',
#   'ambassador',
#   'britain',
#   'morning',
#   'meeting',
#   'british',
#   'foreign',
#   'office',
#   'permanent',
#   'secretary',
#   'philip',
#   'barton',
#   'eu',
#   'official',
#   'said',
#   'latest',
#   'spat',
#   'resulted',
#   'european',
#   'council',
#   'president',
#   'charles',
#   'michel',
#   'rejection',
#   'charges',
#   'vaccine',
#   'nationalism',
#   'levelled',
#   'eu',
#   'comment',
#   'britain',
#   'united_states',
#   'export',
#   'bans',
#   'covid',
#   'vaccine',
#   'doses',
#   'britain',
#   'retorted',
#   'claims',
#   'export',
#   'ban',
#   'restrictions',
#   'completely',
#   'false',
#   'britain',
#   'unilateral',
#   'extension',
#   'grace',
#   'period',
#   'checks',
#   'food',
#   'imports',
#   'northern',
#   'ireland',
#   'eu',
#   'says',
#   'breaches',
#   'terms',
#   'brexit',
#   'divorce',
#   'deal',
#   'initial',
#   'move',
#   'eu',
#   'january',
#   'control',
#   'trade',
#   'across',
#   'border',
#   'northern',
#   'ireland',
#   'ireland',
#   'already',
#   'soured',
#   'relations',
#   'comments',
#   'britain',
#   'top',
#   'adviser',
#   'david',
#   'frost',
#   'sunday',
#   'european',
#   'union',
#   'shake',
#   'ill',
#   'towards',
#   'britain',
#   'gone',
#   'well',
#   'either',
#   'never',
#   'sulk',
#   'moods',
#   'response',
#   'european',
#   'commission',
#   'handles',
#   'relations',
#   'britain',
#   'behalf',
#   'nation',
#   'eu',
#   'seoul',
#   'reuters',
#   'handful',
#   'south',
#   'korean',
#   'hospitals',
#   'designated',
#   'nurses',
#   'using',
#   'specially',
#   'designed',
#   'syringes',
#   'squeeze',
#   'extra',
#   'doses',
#   'coronavirus',
#   'vaccine',
#   'vial',
#   'bid',
#   'stretch',
#   'still',
#   'limited',
#   'number',
#   'vials',
#   'cover',
#   'people',
#   'practice',
#   'raised',
#   'debate',
#   'medical',
#   'safety',
#   'commercial',
#   'concerns',
#   'manufacturers',
#   'charge',
#   'dose',
#   'seoul',
#   'national',
#   'medical',
#   'center',
#   'healthcare',
#   'workers',
#   'say',
#   'actually',
#   'safe',
#   'easy',
#   'process',
#   'brainer',
#   'countries',
#   'struggling',
#   'provide',
#   'enough',
#   'vaccines',
#   'quickly',
#   'two',
#   'designated',
#   'nurses',
#   'take',
#   'shifts',
#   'extract',
#   'doses',
#   'us',
#   'trouble',
#   'getting',
#   'seven',
#   'doses',
#   'vial',
#   'vaccinating',
#   'everyone',
#   'said',
#   'kim',
#   'eun',
#   'suk',
#   'intravenous',
#   'therapy',
#   'specialist',
#   'taking',
#   'shift',
#   'extracting',
#   'doses',
#   'pfizer',
#   'covid',
#   'vaccine',
#   'vials',
#   'officially',
#   'hold',
#   'six',
#   'tuesday',
#   'kim',
#   'said',
#   'centre',
#   'vaccinated',
#   'people',
#   'vials',
#   'pfizer',
#   'vaccine',
#   'co',
#   'developed',
#   'german',
#   'partner',
#   'biontech',
#   'compared',
#   'people',
#   'possible',
#   'extracted',
#   'six',
#   'doses',
#   'vial',
#   'takes',
#   'five',
#   'minutes',
#   'extract',
#   'doses',
#   'using',
#   'low',
#   'dead',
#   'space',
#   'syringes',
#   'designed',
#   'minimise',
#   'residual',
#   'volume',
#   'said',
#   'extraction',
#   'difficult'],
#  ['requires', 'squeezing', 'exact', 'amount', 'syringe'],
#  ['important',
#   'sterilization',
#   'think',
#   'nurse',
#   'would',
#   'able',
#   'pull',
#   'suggestion',
#   'frontline',
#   'nurses',
#   'korea',
#   'disease',
#   'control',
#   'prevention',
#   'agency',
#   'kdca',
#   'said',
#   'providers',
#   'whether',
#   'use',
#   'remaining',
#   'doses',
#   'make',
#   'new',
#   'standard',
#   'mandatory',
#   'said',
#   'could',
#   'burden',
#   'healthcare',
#   'workers',
#   'site',
#   'national',
#   'medical',
#   'center',
#   'president',
#   'chung',
#   'ki',
#   'hyun',
#   'said',
#   'contracts',
#   'manufacturers',
#   'sell',
#   'dose',
#   'roadblock',
#   'site',
#   'healthcare',
#   'workers',
#   'use',
#   'remaining',
#   'doses',
#   'save',
#   'lives',
#   'care',
#   'precision',
#   'extra',
#   'dose',
#   'hard',
#   'extract',
#   'said',
#   'clear',
#   'many',
#   'south',
#   'korean',
#   'clinics',
#   'using',
#   'extra',
#   'doses',
#   'chung',
#   'said',
#   'following',
#   'official',
#   'limit',
#   'means',
#   'throwing',
#   'away',
#   'potentially',
#   'life',
#   'saving',
#   'vaccines',
#   'experts',
#   'divided',
#   'decision',
#   'extract',
#   'extra',
#   'doses',
#   'pooling',
#   'leftover',
#   'vaccine',
#   'multiple',
#   'vials',
#   'lead',
#   'contamination'],
#  ['specialised',
#   'low',
#   'dead',
#   'space',
#   'syringes',
#   'however',
#   'full',
#   'extra',
#   'dose',
#   'typically',
#   'pulled',
#   'single',
#   'pfizer',
#   'vaccine',
#   'vial',
#   'many',
#   'two',
#   'extra',
#   'doses',
#   'astrazeneca',
#   'vaccine',
#   'vials',
#   'urging',
#   'caution',
#   'imprecise',
#   'extraction',
#   'korean',
#   'medical',
#   'association',
#   'kma',
#   'advised',
#   'members',
#   'discard',
#   'remaining',
#   'doses',
#   'vials',
#   'according',
#   'statement',
#   'seen',
#   'reuters',
#   'kdca',
#   'said',
#   'people',
#   'given',
#   'first',
#   'doses',
#   'astrazeneca',
#   'pfizer',
#   'shots',
#   'tuesday',
#   'midnight'],
#  ['south_korea',
#   'reported',
#   'new',
#   'cases',
#   'tuesday',
#   'adding',
#   'total',
#   'coronavirus',
#   'cases',
#   'deaths',
#   'paris',
#   'reuters',
#   'fire',
#   'tore',
#   'data',
#   'complex',
#   'housing',
#   'servers',
#   'run',
#   'cloud',
#   'computing',
#   'company',
#   'ovhcloud',
#   'strasbourg',
#   'eastern',
#   'france',
#   'wednesday',
#   'destroying',
#   'units',
#   'forcing',
#   'temporary',
#   'shutdown',
#   'others',
#   'company',
#   'chief',
#   'executive',
#   'said',
#   'ovhcloud',
#   'monday',
#   'launched',
#   'process',
#   'potential',
#   'ipo',
#   'urged',
#   'clients',
#   'activate',
#   'disaster',
#   'recovery',
#   'plans',
#   'fire',
#   'destroyed',
#   'sbg'],
#  ['part', 'sbg', 'destroyed'],
#  ['firefighters', 'protecting', 'sbg'],
#  ['impact',
#   'sbg',
#   'chief',
#   'executive',
#   'octave',
#   'klaba',
#   'said',
#   'twitter',
#   'reference',
#   'different',
#   'units',
#   'housing',
#   'servers',
#   'access',
#   'site'],
#  ['sbg',
#   'sbg',
#   'sbg',
#   'restarted',
#   'today',
#   'added',
#   'data',
#   'centre',
#   'strasbourg',
#   'one',
#   'ovhcloud',
#   'data',
#   'centres',
#   'france',
#   'globally',
#   'founded',
#   'klaba',
#   'ovhcloud',
#   'biggest',
#   'european',
#   'based',
#   'cloud',
#   'services',
#   'provider',
#   'competing',
#   'u',
#   'giants',
#   'amazon',
#   'web',
#   'services',
#   'microsoft',
#   'azure',
#   'google',
#   'cloud',
#   'dominate',
#   'market',
#   'french',
#   'politicians',
#   'championed',
#   'ovhcloud',
#   'possible',
#   'alternative',
#   'u',
#   'cloud',
#   'services',
#   'providers',
#   'far',
#   'lacked',
#   'scale',
#   'financial',
#   'clout',
#   'dent',
#   'market',
#   'share',
#   'klaba',
#   'said',
#   'fire',
#   'employees',
#   'safe',
#   'london',
#   'reuters',
#   'piers',
#   'morgan',
#   'pugnacious',
#   'british',
#   'presenter',
#   'lost',
#   'high',
#   'profile',
#   'breakfast',
#   'tv',
#   'slot',
#   'attacks',
#   'prince',
#   'harry',
#   'wife',
#   'meghan',
#   'said',
#   'wednesday',
#   'still',
#   'believe',
#   'said',
#   'oprah',
#   'winfrey',
#   'interview',
#   'morgan',
#   'left',
#   'itv',
#   'good',
#   'morning',
#   'britain',
#   'tuesday',
#   'long',
#   'running',
#   'criticism',
#   'meghan',
#   'intensified',
#   'wake',
#   'interview',
#   'winfrey',
#   'revealed',
#   'felt',
#   'suicidal',
#   'living',
#   'royal',
#   'britain',
#   'monday',
#   'said',
#   'believe',
#   'meghan',
#   'markle',
#   'oprah',
#   'interview'],
#  ['time', 'reflect', 'opinion', 'still'],
#  ['ok',
#   'morgan',
#   'said',
#   'characteristically',
#   'combative',
#   'tweet',
#   'wednesday',
#   'morning',
#   'freedom',
#   'speech',
#   'hill',
#   'happy',
#   'die'],
#  ['thanks', 'love', 'hate'],
#  ['spend',
#   'time',
#   'opinions',
#   'told',
#   'million',
#   'twitter',
#   'followers',
#   'added',
#   'photo',
#   'winston',
#   'churchill',
#   'quote',
#   'topic',
#   'free',
#   'speech',
#   'two',
#   'hour',
#   'interview',
#   'plunged',
#   'british',
#   'monarchy',
#   'crisis',
#   'meghan',
#   'said',
#   'royal',
#   'family',
#   'rejected',
#   'pleas',
#   'mental',
#   'health',
#   'support',
#   'someone',
#   'household',
#   'raised',
#   'questions',
#   'colour',
#   'unborn',
#   'son',
#   'skin',
#   'morning',
#   'interview',
#   'aired',
#   'u',
#   'television',
#   'morgan',
#   'said',
#   'good',
#   'morning',
#   'britain',
#   'among',
#   'torrent',
#   'criticisms',
#   'believe',
#   'word',
#   'meghan',
#   'said'],
#  ['tweet',
#   'called',
#   'princess',
#   'pinocchio',
#   'following',
#   'morning',
#   'stormed',
#   'set',
#   'live',
#   'programme',
#   'challenged',
#   'co',
#   'presenter',
#   'stance'],
#  ['later',
#   'day',
#   'itv',
#   'said',
#   'leaving',
#   'monday',
#   'programme',
#   'attracted',
#   'complaints',
#   'britain',
#   'media',
#   'regulator',
#   'announced',
#   'investigation',
#   'harm',
#   'offence',
#   'rules',
#   'morgan',
#   'first',
#   'made',
#   'name',
#   'cut',
#   'throat',
#   'world',
#   'british',
#   'tabloid',
#   'press',
#   'culminating',
#   'stints',
#   'editing',
#   'defunct',
#   'news',
#   'world',
#   'daily',
#   'mirror',
#   'later',
#   'went',
#   'television',
#   'appearing',
#   'judge',
#   'reality',
#   'shows',
#   'america',
#   'got',
#   'talent',
#   'britain',
#   'got',
#   'talent'],
#  ['three',
#   'years',
#   'hosted',
#   'chat',
#   'show',
#   'cnn',
#   'replacing',
#   'larry',
#   'king',
#   'london',
#   'reuters',
#   'london',
#   'police',
#   'chief',
#   'nick',
#   'ephgrave',
#   'said',
#   'hoped',
#   'missing',
#   'woman',
#   'sarah',
#   'everard',
#   'would',
#   'found',
#   'alive',
#   'serving',
#   'police_officer',
#   'arrested',
#   'connection',
#   'disappearance',
#   'searching',
#   'hard',
#   'find',
#   'sarah',
#   'really',
#   'hope',
#   'case',
#   'ephgrave',
#   'assistant',
#   'commissioner',
#   'metropolitan',
#   'police',
#   'service',
#   'said',
#   'asked',
#   'reporters',
#   'still',
#   'alive',
#   'told',
#   'british',
#   'media',
#   'officer',
#   'duty',
#   'time',
#   'year',
#   'old',
#   'disappearance',
#   'said',
#   'could',
#   'give',
#   'details',
#   'whether',
#   'pair',
#   'knew',
#   'long',
#   'man',
#   'police_officer',
#   'seoul',
#   'reuters',
#   'south_korea',
#   'agreed',
#   'increase',
#   'contribution',
#   'cost',
#   'hosting',
#   'u',
#   'troops',
#   'biggest',
#   'annual',
#   'rise',
#   'nearly',
#   'two',
#   'decades',
#   'u',
#   'calls',
#   'greater',
#   'funding',
#   'increase',
#   'take',
#   'south_korea',
#   'contribution',
#   'year',
#   'trillion',
#   'billion'],
#  ['former',
#   'u',
#   'president',
#   'donald',
#   'trump',
#   'accused',
#   'south_korea',
#   'free',
#   'riding',
#   'u',
#   'military',
#   'might',
#   'demanded',
#   'pay',
#   'much',
#   'billion',
#   'year',
#   'agreement',
#   'resolved',
#   'longest',
#   'ever',
#   'vacuum',
#   'lasted',
#   'year',
#   'three',
#   'months',
#   'south_korea',
#   'chief',
#   'negotiator',
#   'jeong',
#   'eun',
#   'bo',
#   'told',
#   'televised',
#   'briefing',
#   'provided',
#   'chance',
#   'reaffirm',
#   'importance',
#   'alliance',
#   'need',
#   'stable',
#   'stationing',
#   'u'],
#  ['forces',
#   'korea',
#   'six',
#   'year',
#   'special',
#   'measures',
#   'agreement',
#   'united_states',
#   'came',
#   'drawn',
#   'negotiations',
#   'boost',
#   'south_korea',
#   'annual',
#   'contribution',
#   'bill',
#   'line',
#   'annual',
#   'defence',
#   'budget',
#   'increase',
#   'year',
#   'foreign',
#   'ministry',
#   'said_statement',
#   'pact',
#   'replaces',
#   'arrangement',
#   'expired',
#   'end',
#   'south_korea',
#   'paid',
#   'million',
#   'year'],
#  ['sides',
#   'agreed',
#   'freeze',
#   'south_korea',
#   'contribution',
#   'ministry',
#   'said',
#   'last',
#   'big',
#   'increase',
#   'contribution',
#   'south_korea',
#   'paid',
#   'previous',
#   'year',
#   'according',
#   'data',
#   'defence',
#   'ministry',
#   'white',
#   'paper',
#   'new',
#   'link',
#   'contribution',
#   'cost',
#   'maintaining',
#   'u',
#   'forces',
#   'defence',
#   'budget',
#   'ministry',
#   'said',
#   'increase',
#   'defence',
#   'budget',
#   'reasonable',
#   'verifiable',
#   'indicator',
#   'reflected',
#   'financial',
#   'security',
#   'capabilities',
#   'shin',
#   'beom',
#   'chul',
#   'security',
#   'expert',
#   'research',
#   'institute',
#   'economy',
#   'society',
#   'seoul',
#   'said',
#   'aligning',
#   'two',
#   'issues',
#   'mistake',
#   'south_korea',
#   'one',
#   'world',
#   'largest',
#   'defence',
#   'spenders',
#   'could',
#   'bring',
#   'budget',
#   'pressure',
#   'u',
#   'troops',
#   'stationed',
#   'south_korea',
#   'help',
#   'defend',
#   'north',
#   'korea',
#   'treaty',
#   'mutual',
#   'defence',
#   'signed',
#   'korean',
#   'war',
#   'ended',
#   'armistice',
#   'peace',
#   'treaty',
#   'treaty',
#   'provided',
#   'basis',
#   'stationing',
#   'u',
#   'forces',
#   'south_korea',
#   'began',
#   'paying',
#   'towards',
#   'costs',
#   'early',
#   'rebuilding',
#   'war',
#   'devastated',
#   'economy',
#   'negotiations',
#   'making',
#   'little',
#   'headway',
#   'last',
#   'pact',
#   'expired',
#   'half',
#   'south',
#   'koreans',
#   'working',
#   'u',
#   'military',
#   'placed',
#   'unpaid',
#   'leave',
#   'prompting',
#   'two',
#   'sides',
#   'scramble',
#   'stopgap',
#   'deal',
#   'bring',
#   'back',
#   'work',
#   'jeong',
#   'said',
#   'accord',
#   'stipulated',
#   'future',
#   'workers',
#   'get',
#   'existing',
#   'salaries',
#   'absence',
#   'new',
#   'deal',
#   'workers',
#   'union',
#   'welcomed',
#   'agreement',
#   'saying',
#   'would',
#   'help',
#   'ensure',
#   'stable',
#   'work',
#   'conditions'],
#  ['without',
#   'thousands',
#   'workers',
#   'would',
#   'forced',
#   'take',
#   'unpaid',
#   'leave',
#   'next',
#   'month',
#   'union',
#   'said'],
#  ['moscow',
#   'reuters',
#   'russia',
#   'state',
#   'communications',
#   'watchdog',
#   'said',
#   'wednesday',
#   'restricting',
#   'use',
#   'twitter',
#   'slowing',
#   'speed',
#   'accusing',
#   'social',
#   'media',
#   'platform',
#   'repeatedly',
#   'failing',
#   'remove',
#   'banned',
#   'content',
#   'site',
#   'roskomnadzor',
#   'threatened',
#   'block',
#   'service',
#   'completely',
#   'said',
#   'posts',
#   'containing',
#   'illegal',
#   'content',
#   'wednesday',
#   'twitter',
#   'like',
#   'u',
#   'social',
#   'media',
#   'used',
#   'widely',
#   'inside',
#   'russia',
#   'allies',
#   'kremlin',
#   'critic',
#   'alexei',
#   'navalny',
#   'whose',
#   'jailing',
#   'last',
#   'month',
#   'prompted',
#   'nationwide',
#   'protests',
#   'slowing',
#   'applied',
#   'mobile',
#   'devices',
#   'non',
#   'mobile',
#   'devices',
#   'regulator',
#   'said_statement',
#   'website',
#   'twitter',
#   'continues',
#   'ignore',
#   'requirements',
#   'law',
#   'enforcement',
#   'measures',
#   'continued',
#   'line',
#   'response',
#   'regulations',
#   'way',
#   'blocking',
#   'said',
#   'twitter',
#   'immediately',
#   'respond',
#   'emailed',
#   'request',
#   'comment',
#   'wednesday',
#   'move',
#   'comes',
#   'amid',
#   'mounting',
#   'efforts',
#   'moscow',
#   'exert',
#   'greater',
#   'influence',
#   'u',
#   'social',
#   'media',
#   'platforms',
#   'frustrations',
#   'authorities',
#   'say',
#   'failure',
#   'follow',
#   'russian',
#   'laws',
#   'last',
#   'december',
#   'parliament',
#   'lower',
#   'house',
#   'backed',
#   'big',
#   'new',
#   'fines',
#   'platforms',
#   'fail',
#   'delete',
#   'banned',
#   'content',
#   'another',
#   'bill',
#   'would',
#   'allow',
#   'restricted',
#   'discriminate',
#   'russian',
#   'media']]

# %%
model = Word2Vec(sentences=all_sentences, min_count=3, size=1000, workers=10)
# Out:
# 2021-03-13 22:02:20,341 : INFO : collecting all words and their counts
# 2021-03-13 22:02:20,341 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-03-13 22:02:20,365 : INFO : collected 16524 word types from a corpus of 125043 raw words and 6018 sentences
# 2021-03-13 22:02:20,365 : INFO : Loading a fresh vocabulary
# 2021-03-13 22:02:20,384 : INFO : effective_min_count=3 retains 7461 unique words (45% of original 16524, drops 9063)
# 2021-03-13 22:02:20,386 : INFO : effective_min_count=3 leaves 113517 word corpus (90% of original 125043, drops 11526)
# 2021-03-13 22:02:20,401 : INFO : deleting the raw counts dictionary of 16524 items
# 2021-03-13 22:02:20,403 : INFO : sample=0.001 downsamples 7 most-common words
# 2021-03-13 22:02:20,403 : INFO : downsampling leaves estimated 111947 word corpus (98.6% of prior 113517)
# 2021-03-13 22:02:20,418 : INFO : estimated required memory for 7461 words and 1000 dimensions: 63418500 bytes
# 2021-03-13 22:02:20,419 : INFO : resetting layer weights
# 2021-03-13 22:02:21,554 : INFO : training model with 10 workers on 7461 vocabulary and 1000 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2021-03-13 22:02:21,701 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-03-13 22:02:21,703 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-03-13 22:02:21,710 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-03-13 22:02:21,713 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-03-13 22:02:21,719 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-03-13 22:02:21,725 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-03-13 22:02:21,728 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-03-13 22:02:21,754 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-03-13 22:02:21,770 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-03-13 22:02:21,778 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-03-13 22:02:21,779 : INFO : EPOCH - 1 : training on 125043 raw words (111949 effective words) took 0.2s, 516110 effective words/s
# 2021-03-13 22:02:21,946 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-03-13 22:02:21,949 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-03-13 22:02:21,950 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-03-13 22:02:21,950 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-03-13 22:02:21,951 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-03-13 22:02:21,952 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-03-13 22:02:21,953 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-03-13 22:02:21,990 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-03-13 22:02:21,997 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-03-13 22:02:22,011 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-03-13 22:02:22,012 : INFO : EPOCH - 2 : training on 125043 raw words (111936 effective words) took 0.2s, 494786 effective words/s
# 2021-03-13 22:02:22,179 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-03-13 22:02:22,182 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-03-13 22:02:22,182 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-03-13 22:02:22,183 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-03-13 22:02:22,183 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-03-13 22:02:22,184 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-03-13 22:02:22,184 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-03-13 22:02:22,217 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-03-13 22:02:22,229 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-03-13 22:02:22,244 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-03-13 22:02:22,245 : INFO : EPOCH - 3 : training on 125043 raw words (111947 effective words) took 0.2s, 498657 effective words/s
# 2021-03-13 22:02:22,416 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-03-13 22:02:22,417 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-03-13 22:02:22,417 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-03-13 22:02:22,418 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-03-13 22:02:22,418 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-03-13 22:02:22,418 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-03-13 22:02:22,419 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-03-13 22:02:22,452 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-03-13 22:02:22,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-03-13 22:02:22,491 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-03-13 22:02:22,492 : INFO : EPOCH - 4 : training on 125043 raw words (111952 effective words) took 0.2s, 466373 effective words/s
# 2021-03-13 22:02:22,668 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2021-03-13 22:02:22,671 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2021-03-13 22:02:22,671 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-03-13 22:02:22,671 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-03-13 22:02:22,672 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-03-13 22:02:22,672 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-03-13 22:02:22,672 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-03-13 22:02:22,704 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-03-13 22:02:22,715 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-03-13 22:02:22,732 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-03-13 22:02:22,732 : INFO : EPOCH - 5 : training on 125043 raw words (111929 effective words) took 0.2s, 479780 effective words/s
# 2021-03-13 22:02:22,733 : INFO : training on a 625215 raw words (559713 effective words) took 1.2s, 474677 effective words/s
# 2021-03-13 22:02:22,733 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
x_vals, y_vals, labels = reduce_dimensions(model)

try:
    get_ipython()
except Exception:
    plot_function = plot_with_matplotlib
else:
    plot_function = plot_with_plotly
plot_function(x_vals, y_vals, labels, groups)
# Out:
# C:\Users\ryan\anaconda3\envs\word2vec\lib\site-packages\_plotly_utils\basevalidators.py:575: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-a110b3814500> in <module>
#       7 else:
#       8     plot_function = plot_with_plotly
# ----> 9 plot_function(x_vals, y_vals, labels, groups)
#
# <ipython-input-78-2b2d1dde4cc3> in plot_with_plotly(x_vals, y_vals, labels, colors, plot_in_notebook)
#      30
#      31
# ---> 32     trace = go.Scatter(x=x_vals, y=y_vals, fill=colors, mode='text', text=labels)
#      33     data = [trace]
#      34
#
# ~\anaconda3\envs\word2vec\lib\site-packages\plotly\graph_objs\_scatter.py in __init__(self, arg, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, line, marker, meta, metasrc, mode, name, opacity, orientation, r, rsrc, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, t, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, tsrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yperiod, yperiod0, yperiodalignment, ysrc, **kwargs)
#    2948         _v = fill if fill is not None else _v
#    2949         if _v is not None:
# -> 2950             self["fill"] = _v
#    2951         _v = arg.pop("fillcolor", None)
#    2952         _v = fillcolor if fillcolor is not None else _v
#
# ~\anaconda3\envs\word2vec\lib\site-packages\plotly\basedatatypes.py in __setitem__(self, prop, value)
#    4802                 # ### Handle simple property ###
#    4803                 else:
# -> 4804                     self._set_prop(prop, value)
#    4805             else:
#    4806                 # Make sure properties dict is initialized
#
# ~\anaconda3\envs\word2vec\lib\site-packages\plotly\basedatatypes.py in _set_prop(self, prop, val)
#    5146                 return
#    5147             else:
# -> 5148                 raise err
#    5149
#    5150         # val is None
#
# ~\anaconda3\envs\word2vec\lib\site-packages\plotly\basedatatypes.py in _set_prop(self, prop, val)
#    5141
#    5142         try:
# -> 5143             val = validator.validate_coerce(val)
#    5144         except ValueError as err:
#    5145             if self._skip_invalid:
#
# ~\anaconda3\envs\word2vec\lib\site-packages\_plotly_utils\basevalidators.py in validate_coerce(self, v)
#     598             v = self.perform_replacemenet(v)
#     599             if not self.in_values(v):
# --> 600                 self.raise_invalid_val(v)
#     601         return v
#     602
#
# ~\anaconda3\envs\word2vec\lib\site-packages\_plotly_utils\basevalidators.py in raise_invalid_val(self, v, inds)
#     275                 name += "[" + str(i) + "]"
#     276
# --> 277         raise ValueError(
#     278             """
#     279     Invalid value of type {typ} received for the '{name}' property of {pname}
#
# ValueError:
#     Invalid value of type 'numpy.ndarray' received for the 'fill' property of scatter
#         Received value: array([7, 3, 5, ..., 6, 6, 1])
#
#     The 'fill' property is an enumeration that may be specified as:
#       - One of the following enumeration values:
#             ['none', 'tozeroy', 'tozerox', 'tonexty', 'tonextx',
#             'toself', 'tonext']

# %%
plot_function(x_vals, y_vals, labels, groups)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-43b9bb136ecb> in <module>
# ----> 1 plot_function(x_vals, y_vals, labels, groups)
#
# <ipython-input-89-7a8525bb7cff> in plot_with_plotly(x_vals, y_vals, labels, cluster, plot_in_notebook)
#      31
#      32     trace = go.Scatter(x=x_vals, y=y_vals, mode='markers+text', text=labels)
# ---> 33     trace.update_traces(textposition='top center')
#      34     data = [trace]
#      35
#
# AttributeError: 'Scatter' object has no attribute 'update_traces'

# %%
X = []
zip_obj = zip(x_vals,y_vals)
for x,y in zip_obj:
    X.append([x,y])
X
# Out:
# [[-35.534153, -58.033134],
#  [-0.6795189, 1.1122189],
#  [-86.66726, 6.112153],
#  [-84.108986, 11.584095],
#  [17.918665, 70.84267],
#  [-46.13521, -48.114113],
#  [71.22282, -32.086407],
#  [-88.11314, -12.248837],
#  [-14.720884, 47.979362],
#  [4.4460893, 25.28452],
#  [88.04137, -9.998778],
#  [2.8408856, 48.035053],
#  [-31.640581, -61.704777],
#  [-47.609562, -9.321021],
#  [-51.95185, 39.196312],
#  [41.23847, -57.211502],
#  [-62.057312, -29.054274],
#  [-45.900204, -48.365646],
#  [-13.5169115, -47.4234],
#  [-48.634277, -45.231876],
#  [-35.791767, -57.778122],
#  [-41.371998, 7.475142],
#  [-66.76781, -25.369268],
#  [-59.10072, -31.934818],
#  [-46.880447, 0.62855715],
#  [-86.89416, 5.522057],
#  [-48.390575, -6.0174794],
#  [-87.73498, 2.998351],
#  [-65.350006, -26.408249],
#  [-30.58654, -62.678715],
#  [-61.35419, -29.69918],
#  [-4.5231586, 74.62926],
#  [-38.98038, -54.837597],
#  [-51.60552, 38.968754],
#  [-54.21578, -37.88984],
#  [-85.51165, 8.769006],
#  [-17.11207, 9.250542],
#  [-18.121017, 1.789808],
#  [-52.673485, -39.943813],
#  [84.91078, 0.8277431],
#  [-45.609833, -48.66563],
#  [74.25066, -28.889015],
#  [-54.413445, -37.62626],
#  [-88.50034, 0.018109629],
#  [-33.66831, -59.82099],
#  [30.072824, 12.264439],
#  [61.89538, -11.860784],
#  [40.61167, -58.43553],
#  [-61.43093, -29.625881],
#  [-56.76461, -34.60085],
#  [32.976868, 12.582549],
#  [-35.411324, -58.148922],
#  [-54.50747, -37.50687],
#  [-79.6044, 18.85547],
#  [-31.761896, -61.58514],
#  [-32.703735, -60.725838],
#  [-67.738304, 33.16655],
#  [-82.859474, 13.836929],
#  [-48.22573, -45.73152],
#  [78.05534, -24.172308],
#  [-30.207405, -63.038235],
#  [-5.922684, -2.0501688],
#  [-66.421005, 34.4658],
#  [43.081226, 31.575045],
#  [-33.11573, -60.342525],
#  [-22.403084, 31.910091],
#  [33.95346, -67.180504],
#  [-82.30502, 14.771579],
#  [35.27911, -65.81764],
#  [69.06855, -34.06132],
#  [-11.318682, 74.57493],
#  [-1.3388172, -34.748657],
#  [-48.5712, 33.595467],
#  [20.764454, 67.581406],
#  [-31.67946, -61.665756],
#  [-56.93856, -34.38506],
#  [-64.58388, 3.0981746],
#  [-88.93083, -8.833743],
#  [32.94894, -68.19937],
#  [-87.81395, -13.163942],
#  [-88.3594, 0.681139],
#  [-39.369473, -54.491356],
#  [77.39895, -25.02366],
#  [-60.875587, -30.152466],
#  [-53.15337, 19.523626],
#  [-61.42261, 8.791546],
#  [-86.98052, -14.899764],
#  [-66.28247, -25.719666],
#  [-86.55386, 6.3840857],
#  [30.093678, 12.691335],
#  [-68.335434, -8.783017],
#  [-46.730785, -47.46545],
#  [-87.31312, 4.3614416],
#  [-4.7098627, -27.640673],
#  [-32.091125, 8.128093],
#  [-20.307407, 41.05937],
#  [-28.759254, -15.765198],
#  [-36.932972, -56.70812],
#  [15.06942, -4.7719364],
#  [-63.845917, 4.606697],
#  [-52.036293, -40.801525],
#  [23.301462, 14.0707],
#  [-88.93979, -2.5972183],
#  [29.435038, 12.600037],
#  [-49.90704, -43.629585],
#  [-69.22768, 31.596338],
#  [-89.072754, -7.6887507],
#  [-13.153663, 47.249374],
#  [-47.367283, -46.73209],
#  [-88.808685, -1.6869165],
#  [-39.482723, -54.389256],
#  [-38.285072, -55.45462],
#  [-36.51549, -57.102093],
#  [-14.573469, -44.92998],
#  [-64.915276, -26.741241],
#  [0.079621494, 22.542694],
#  [79.01148, -22.88465],
#  [-53.19229, -39.253773],
#  [-48.65473, 29.029068],
#  [30.459274, -17.148252],
#  [8.184562, 73.73592],
#  [-88.93968, -2.5957308],
#  [-54.82212, 40.072742],
#  [-39.704445, -54.190834],
#  [-42.480762, -51.668938],
#  [-62.568047, -28.608654],
#  [-32.197716, -61.192593],
#  [20.348074, 67.34326],
#  [-58.995247, -32.04342],
#  [-88.76017, -9.742095],
#  [-30.486303, -62.772095],
#  [-33.67893, -59.80921],
#  [-52.623672, 20.26409],
#  [-87.75703, -13.313731],
#  [-45.204086, -49.069324],
#  [-83.06048, 13.487288],
#  [-89.01262, -3.22761],
#  [-61.730476, 38.188923],
#  [-49.20336, -44.525974],
#  [-73.6622, 26.543941],
#  [-21.194738, -6.6766887],
#  [-46.53133, -47.685146],
#  [-30.46032, -62.796417],
#  [74.54857, 3.7561388],
#  [-36.19751, 9.169077],
#  [-56.870132, -34.47086],
#  [-87.21855, -14.483811],
#  [-76.15554, 23.486515],
#  [63.615784, -37.927757],
#  [-53.79472, -38.451935],
#  [-46.866844, -47.307823],
#  [-56.622078, 15.2002],
#  [-78.3911, 20.543785],
#  [-50.980175, 22.755411],
#  [-20.458643, 22.90808],
#  [-48.300377, -45.64158],
#  [6.4418545, -10.787375],
#  [-84.20336, 11.4114895],
#  [50.32606, 1.6266899],
#  [87.22128, -2.7492096],
#  [-42.094345, -52.02247],
#  [-38.065323, -55.655613],
#  [64.783615, -37.024506],
#  [1.3102994, 49.54721],
#  [16.38107, 40.705254],
#  [-50.585915, -42.74428],
#  [-35.619274, -57.951645],
#  [-30.918915, -62.365074],
#  [-40.396885, -53.568817],
#  [-50.35141, -43.05429],
#  [-47.96738, -46.037605],
#  [-49.74225, 36.601875],
#  [-17.529024, 16.337502],
#  [49.689087, 5.8902783],
#  [-46.994637, -47.163788],
#  [-22.306032, -42.08434],
#  [-35.327007, -58.231567],
#  [-51.645397, -41.325554],
#  [72.22262, -31.092215],
#  [58.246284, -40.319042],
#  [-74.07385, 26.04977],
#  [-71.8533, 28.676626],
#  [-30.410063, -62.83561],
#  [25.529398, 65.25926],
#  [-47.406525, -0.59798765],
#  [76.05878, -26.76358],
#  [15.926971, 42.690105],
#  [-40.006893, -53.92039],
#  [17.258652, -44.22607],
#  [77.21238, 4.234668],
#  [49.697105, 8.884923],
#  [-32.02045, -61.35475],
#  [-43.431416, -50.782127],
#  [-48.5049, -45.390724],
#  [-35.26868, -58.284966],
#  [-16.650663, 45.93226],
#  [28.999485, -24.191393],
#  [-42.50853, -51.64351],
#  [65.12739, -37.362495],
#  [-5.6488285, -2.109953],
#  [-89.11623, -4.708207],
#  [-89.05002, -3.6241417],
#  [-88.83298, -9.399241],
#  [37.776127, -62.93739],
#  [-72.42944, 28.016777],
#  [-0.14086749, -27.129446],
#  [2.470063, 4.675393],
#  [-34.53481, -58.989296],
#  [53.991833, -22.552896],
#  [2.1896236, -67.32285],
#  [88.10437, -4.2667785],
#  [-44.076714, 5.6063976],
#  [-44.695057, -49.568726],
#  [-45.2789, -48.99812],
#  [-45.24077, -49.03596],
#  [-5.323699, -3.005168],
#  [-55.822872, -35.79625],
#  [27.266586, 64.238945],
#  [80.90887, 3.5785184],
#  [-82.076065, 15.1465435],
#  [-39.36736, -54.492275],
#  [-34.11045, 9.50173],
#  [54.856716, -21.208372],
#  [22.67632, -3.3394785],
#  [74.58404, -28.503384],
#  [32.284706, -68.860085],
#  [67.93231, -2.5044866],
#  [-79.74485, 18.657522],
#  [-48.463295, -45.44167],
#  [33.344948, -67.79961],
#  [-40.782173, 7.6838336],
#  [-4.1422954, -72.55172],
#  [-20.023474, 25.286453],
#  [28.996374, -71.94202],
#  [-30.35002, -34.011795],
#  [-67.19808, -3.771682],
#  [-67.43517, -4.6714897],
#  [-59.463043, -31.571157],
#  [-39.359844, -54.49904],
#  [-89.10602, -4.400729],
#  [-69.04462, 31.79222],
#  [-46.21878, 1.9445971],
#  [24.360703, -4.475189],
#  [46.155033, 38.67413],
#  [-86.68747, 6.0618553],
#  [-21.210428, 27.830881],
#  [-22.799057, 29.292767],
#  [-87.04701, 5.1125464],
#  [-30.836994, -62.43866],
#  [-81.72445, 15.707185],
#  [-31.295176, -19.914013],
#  [-49.52632, 36.227962],
#  [-31.363945, -61.95576],
#  [-68.924095, -13.065247],
#  [-53.72432, 18.752867],
#  [-48.483463, 30.612703],
#  [4.5366693, 46.181488],
#  [27.94324, -19.140476],
#  [-46.059322, -48.19418],
#  [59.949486, -14.423521],
#  [35.19867, -65.90096],
#  [-84.73693, 10.36055],
#  [-78.31993, 20.643122],
#  [-85.33617, 9.14681],
#  [-87.44824, -14.0368],
#  [-88.88302, -2.1776447],
#  [-89.13153, -6.76899],
#  [-85.550804, 8.683264],
#  [-76.54499, 22.993332],
#  [-63.785824, 4.7276525],
#  [-49.24608, 35.643085],
#  [-54.92401, -36.95704],
#  [17.089737, -46.088818],
#  [-26.739822, -38.1457],
#  [75.90117, -26.921864],
#  [-41.48451, -52.58216],
#  [-54.200474, -37.90746],
#  [-70.71296, 29.963633],
#  [-39.480045, -54.391712],
#  [28.368534, -72.46357],
#  [16.479057, 41.86721],
#  [-48.46049, 30.867823],
#  [-56.83596, 14.929903],
#  [-39.17014, 8.37389],
#  [-35.036366, -58.508892],
#  [-53.026855, -39.475018],
#  [8.731324, 46.6604],
#  [-59.345676, -31.309088],
#  [3.065278, -68.48882],
#  [5.924635, -63.23092],
#  [-89.115616, -7.1547613],
#  [-36.971973, -56.670826],
#  [65.84344, -5.9657993],
#  [65.98745, -5.7280416],
#  [-65.84949, -26.036032],
#  [-66.29813, -0.9756143],
#  [70.210945, -33.028873],
#  [-0.08798294, 17.396217],
#  [28.808966, -72.0986],
#  [-50.97287, 22.771149],
#  [-48.203106, -45.757645],
#  [-8.168622, 49.272015],
#  [45.29374, 35.923615],
#  [-48.327972, -5.9384727],
#  [-37.433773, -56.237267],
#  [-65.98561, 34.868168],
#  [-48.55112, -45.332367],
#  [-2.3061666, -0.022185262],
#  [26.593899, 33.06053],
#  [46.17755, -40.729977],
#  [-42.78952, -51.37447],
#  [-25.350697, -40.342808],
#  [-54.261784, 39.994785],
#  [-56.75542, -34.615944],
#  [14.428096, 70.369545],
#  [-82.117256, 15.0804],
#  [84.49609, 1.2360497],
#  [-21.933449, 68.09],
#  [18.830502, 16.839264],
#  [-36.76329, -56.868336],
#  [-87.896255, 2.4553201],
#  [-58.97294, 39.34299],
#  [-43.352608, -50.85505],
#  [62.243988, -38.718613],
#  [-39.957287, -53.967587],
#  [16.608265, 70.8804],
#  [-56.781277, -34.58207],
#  [-4.743325, -1.6965723],
#  [37.806854, -62.8833],
#  [66.663826, -4.6020193],
#  [-33.771324, -59.72381],
#  [-35.421406, -58.139088],
#  [-65.114525, -26.58795],
#  [87.64626, -3.8154583],
#  [49.609093, 0.87050253],
#  [33.994892, -67.13861],
#  [-45.48585, -48.79051],
#  [-66.491356, -25.555714],
#  [67.40456, -3.3734677],
#  [13.96309, -3.2894087],
#  [-63.89575, 36.64757],
#  [-86.97601, 5.3075666],
#  [-37.091087, -56.55895],
#  [-35.874313, 9.142941],
#  [-58.01928, -33.1196],
#  [-50.117397, -43.36023],
#  [-62.193367, -28.936283],
#  [-82.946785, 13.688267],
#  [22.992737, 36.26099],
#  [-57.984554, -33.156826],
#  [-30.422539, -29.40416],
#  [-88.952446, -8.687837],
#  [20.23814, 15.738403],
#  [45.308567, -40.276157],
#  [37.831818, 11.982469],
#  [-36.408905, -57.202713],
#  [67.87064, -2.608677],
#  [-39.05864, -54.76403],
#  [-5.5026264, -43.13969],
#  [0.23596711, 23.348482],
#  [-49.008564, 27.321825],
#  [-87.41245, 4.086201],
#  [-57.943516, -33.194324],
#  [34.65516, 11.936052],
#  [-49.465454, 36.112396],
#  [-67.08618, -3.3869314],
#  [-65.69118, 0.6387831],
#  [-53.94526, -38.247112],
#  [-43.613552, -50.604313],
#  [-71.86594, 28.663122],
#  [-30.442656, -62.813236],
#  [-0.039250378, 48.26665],
#  [-32.713047, -19.5813],
#  [-46.896275, 0.600977],
#  [3.65662, 75.14765],
#  [22.674116, 38.132774],
#  [1.4721692, 12.903514],
#  [4.6404634, 25.354107],
#  [2.9738972, 8.282396],
#  [-57.75361, -33.42266],
#  [67.81457, -2.6969588],
#  [1.0889093, -16.92358],
#  [-86.89999, 5.5116496],
#  [-38.179405, -55.54938],
#  [17.476725, 17.81798],
#  [14.609461, 41.337677],
#  [88.115166, -6.1394014],
#  [28.739336, 12.576589],
#  [46.513283, -3.0845137],
#  [-88.87607, -2.123427],
#  [-18.15411, 4.058639],
#  [10.692964, 24.871483],
#  [-88.22489, 1.2541012],
#  [-48.999275, -44.778336],
#  [-59.91167, 10.958875],
#  [73.12471, -30.144186],
#  [-57.659492, -33.538986],
#  [42.46746, -54.668343],
#  [15.469864, 19.834587],
#  [1.1467057, 75.17711],
#  [25.176159, -5.0557923],
#  [-76.68066, 22.816677],
#  [-32.94462, -60.498333],
#  [-62.333206, 7.3173366],
#  [75.20637, 3.9687946],
#  [-40.3338, 7.9468307],
#  [39.458553, 31.093374],
#  [-39.272995, -54.576473],
#  [-52.493336, 20.437082],
#  [30.29922, -70.787384],
#  [-69.309845, 31.50911],
#  [1.7830534, 47.391037],
#  [-8.811741, -76.44941],
#  [56.253418, -19.233044],
#  [-46.59452, -47.61621],
#  [-7.1606464, -2.227764],
#  [-53.216244, -39.224125],
#  [52.05507, -40.996307],
#  [-54.518074, -37.49355],
#  [18.864985, 69.46071],
#  [37.907593, -62.753613],
#  [-52.221317, -40.546513],
#  [42.41221, 31.484552],
#  [-64.70331, 2.8456097],
#  [-59.45046, -31.588339],
#  [-88.08622, 1.7795174],
#  [41.742493, 32.11677],
#  [-68.29083, -8.548508],
#  [-18.381506, 21.382484],
#  [14.801645, 19.427067],
#  [0.16353005, 23.224329],
#  [61.615627, -12.241374],
#  [-59.107895, -31.931408],
#  [19.612465, 39.566254],
#  [-14.777431, 48.778408],
#  [64.86557, -36.890614],
#  [79.432, -22.294523],
#  [19.325813, 16.723557],
#  [-87.27638, 4.4676924],
#  [8.048449, 73.83278],
#  [14.175473, 43.284386],
#  [-84.10288, 11.5992565],
#  [-47.061165, -47.08697],
#  [16.137756, 18.840555],
#  [-3.8938277, 75.55573],
#  [-60.16698, 38.95956],
#  [48.667, 9.037479],
#  [-50.189865, -43.265354],
#  [-23.59379, -42.670383],
#  [-34.515835, -59.006794],
#  [-33.451702, -60.024734],
#  [-13.821568, 46.81863],
#  [-89.07569, -7.6532445],
#  [44.663082, 11.639332],
#  [-1.4543617, 74.70056],
#  [-68.63494, -10.70927],
#  [-37.809155, -55.885715],
#  [-40.245693, -53.70766],
#  [45.4071, 36.452835],
#  [29.674313, 60.13468],
#  [87.41451, -3.2037838],
#  [65.43588, -6.6243443],
#  [-3.2789147, -40.910473],
#  [-54.996796, 40.083477],
#  [-36.1574, -57.43605],
#  [-0.37108463, 75.92827],
#  [-49.22487, -44.497456],
#  [41.379448, -56.931454],
#  [47.99417, -2.7188299],
#  [-46.215614, 1.9364152],
#  [9.208145, 72.75688],
#  [1.5720954, -20.444105],
#  [-36.502132, -57.114044],
#  [-11.925497, -46.691525],
#  [-31.967175, -61.403122],
#  [-48.036736, -2.675116],
#  [-52.77971, 20.039743],
#  [-79.484634, 19.02403],
#  [-88.26388, 1.0861758],
#  [-60.014114, 39.02059],
#  [-55.68124, -35.98038],
#  [16.735954, -48.53861],
#  [39.87462, 54.177055],
#  [-81.42005, 16.17481],
#  [-35.169342, -58.38226],
#  [-66.82204, -25.33727],
#  [62.324745, -38.66645],
#  [23.203604, 14.433114],
#  [64.0317, -8.799561],
#  [2.8932476, 7.6637444],
#  [-68.919334, -12.986664],
#  [-0.68606293, -70.79782],
#  [-42.246433, -51.886112],
#  [-86.610214, 6.2481523],
#  [-67.13872, -3.555212],
#  [-34.13308, -24.186031],
#  [64.21899, -37.922432],
#  [49.400623, -0.6415488],
#  [54.550686, -21.669542],
#  [-48.591537, 33.689926],
#  [24.357822, 66.276],
#  [55.577778, -20.171843],
#  [-15.787734, 8.326919],
#  [42.34413, 12.38782],
#  [-34.441418, -59.07948],
#  [-66.30528, -0.99410546],
#  [-33.65745, -59.831074],
#  [-37.365986, -56.302002],
#  [-89.069145, -7.7282495],
#  [-35.596336, -57.973267],
#  [-52.6774, 39.533955],
#  [-26.996235, -15.202389],
#  [-85.7643, 8.202707],
#  [-75.283394, 24.58106],
#  [-50.13871, 24.38307],
#  [14.446599, 20.674505],
#  [-88.779335, -1.5005348],
#  [-30.278913, -35.021484],
#  [-73.42814, 26.831509],
#  [-47.729256, -10.841342],
#  [27.657034, 63.40482],
#  [26.149384, 63.08546],
#  [-50.830135, 38.17983],
#  [18.6791, -44.761745],
#  [-61.964615, 38.040092],
#  [-36.287006, -57.318195],
#  [30.91008, 59.07887],
#  [-68.92453, -13.059922],
#  [-48.425755, 31.306122],
#  [47.850883, -2.08777],
#  [45.070316, 34.244312],
#  [8.292289, -11.304984],
#  [-40.231525, -53.720493],
#  [42.368652, -54.88142],
#  [-33.314926, 8.425544],
#  [41.616352, -56.45253],
#  [0.12564613, 15.754028],
#  [4.7230783, 48.623154],
#  [-34.233875, -59.275024],
#  [-38.503784, -55.25955],
#  [14.326629, 72.194565],
#  [-68.53092, -9.9872875],
#  [-58.60998, -32.462803],
#  [-31.487349, -61.846745],
#  [-47.734497, -1.5576018],
#  [-67.76466, -6.05629],
#  [22.299767, 65.48899],
#  [-66.98752, 33.92049],
#  [-50.630085, 23.390877],
#  [-41.75001, -52.343002],
#  [-41.986618, 6.891058],
#  [43.718487, -40.21369],
#  [-6.708738, -2.7093997],
#  [-0.84575206, -69.993515],
#  [58.01178, -16.893847],
#  [23.052935, 36.1573],
#  [53.04397, -41.038437],
#  [18.580778, 40.04372],
#  [-56.362686, -35.10574],
#  [35.44359, -65.638695],
#  [-4.675907, -1.5731202],
#  [46.849464, 11.065483],
#  [15.413659, 69.305855],
#  [-79.85928, 18.494675],
#  [-51.710407, -41.23465],
#  [39.281612, 53.32219],
#  [37.918537, -62.733585],
#  [50.904877, -41.286003],
#  [21.703974, -35.88865],
#  [-1.6582836, -30.8822],
#  [8.060077, -57.431583],
#  [35.166992, 30.617722],
#  [70.09752, -33.13673],
#  [-13.858454, 73.69707],
#  [-89.09671, -4.2373357],
#  [-46.864563, -47.31061],
#  [37.855343, -62.82228],
#  [-72.37694, 28.077703],
#  [-62.957104, 37.36822],
#  [-49.2629, -44.449886],
#  [21.209866, 36.005993],
#  [2.338587, 11.437557],
#  [32.45923, -68.68745],
#  [-40.73058, -53.264946],
#  [43.01606, 12.015052],
#  [-53.666237, -38.623085],
#  [-65.89325, -26.004711],
#  [-56.28238, 39.902172],
#  [-37.85316, -55.848816],
#  [-30.575994, -62.686703],
#  [85.5804, 0.037285544],
#  [-84.08964, 11.621831],
#  [-49.738716, -43.845467],
#  [-21.4542, 69.06928],
#  [80.791916, 3.6250641],
#  [-88.96382, -2.7985153],
#  [-72.637115, 27.77228],
#  [43.136787, 49.64392],
#  [-48.291656, -4.347001],
#  [-88.01102, 2.053289],
#  [-58.894665, -32.153996],
#  [-32.00211, -61.373528],
#  [-46.430706, -47.79477],
#  [43.31498, 50.59945],
#  [29.00286, -21.668686],
#  [-50.298363, 24.050173],
#  [-60.495876, -30.520475],
#  [26.305813, 34.71767],
#  [-7.5622935, -43.922253],
#  [-48.02754, -2.7242482],
#  [-63.259647, 37.142982],
#  [-35.61258, -57.958454],
#  [-21.475683, 23.228302],
#  [-51.53488, -41.472397],
#  [17.215845, -49.433437],
#  [2.9764729, 11.160967],
#  [-30.98581, -62.302612],
#  [-0.3350419, -28.22629],
#  [-85.44923, 8.908768],
#  [-53.677357, 18.815125],
#  [-17.858517, -1.3257267],
#  [57.83951, -17.117716],
#  [-21.00301, -6.0163593],
#  [-32.69821, -60.7307],
#  [53.70792, -23.019556],
#  [38.140232, -62.424606],
#  [0.6936508, -22.254478],
#  [-51.120026, -42.02838],
#  [-86.54121, 6.40834],
#  [-88.88519, -2.1808524],
#  [-15.994553, 3.7618444],
#  [-21.051214, 67.48604],
#  [-86.48479, 6.55264],
#  [77.58373, 4.2348824],
#  [-45.40023, -48.879322],
#  [-51.993362, -40.859077],
#  [-18.27763, 2.0502007],
#  [17.328524, -45.13599],
#  [17.115582, 39.677616],
#  [47.07287, -40.826588],
#  [-40.91855, 7.717996],
#  [-52.595917, -40.051132],
#  [-80.728035, 17.207432],
#  [28.360823, -20.789455],
#  [-68.31083, 32.571484],
#  [-12.836471, -46.635864],
#  [-31.707994, -23.072903],
#  [11.703516, 22.696789],
#  [47.06368, 10.339623],
#  [65.30201, -6.82742],
#  [-64.74853, -26.871584],
#  [-89.13077, -6.774364],
#  [-19.57255, -3.61437],
#  [-18.638678, 0.55162555],
#  [15.36394, 42.266174],
#  [-55.850044, -35.762253],
#  [-47.830147, -46.198452],
#  [-5.5426445, -74.803535],
#  [-62.3045, 37.82174],
#  [43.00202, -39.937332],
#  [-48.048004, -45.943478],
#  [72.79213, -30.501518],
#  [-36.03818, -57.553295],
#  [48.082886, 9.68314],
#  [-22.249044, -8.262614],
#  [-51.904575, -40.9774],
#  [2.8936117, 24.77763],
#  [-58.656147, 12.651663],
#  [-31.764132, -61.58027],
#  [20.712076, -38.014782],
#  [58.015408, -16.889393],
#  [-62.171425, 7.587656],
#  [36.077854, 57.290977],
#  [-67.415855, -24.935892],
#  [41.054573, 31.27182],
#  [57.91824, -17.013868],
#  [-10.352837, 74.66898],
#  [-24.234974, 33.30153],
#  [-86.82808, 5.7001686],
#  [-68.59314, -10.409161],
#  [-65.23539, 1.6938853],
#  [-60.49968, -30.515308],
#  [9.334876, -8.966163],
#  [62.492085, -11.038222],
#  [-31.720093, -61.623474],
#  [-87.03787, -14.805367],
#  [-85.76842, 8.196917],
#  [-88.96838, -8.57302],
#  [-87.44174, -14.049544],
#  [-88.56035, -10.58806],
#  [-21.31132, 27.15392],
#  [88.07623, -5.851669],
#  [46.800285, 40.14047],
#  [56.79323, -18.498165],
#  [55.958195, -19.638945],
#  [73.85762, -29.341238],
#  [13.707232, -51.907257],
#  [-55.214317, 16.891464],
#  [-35.13305, -58.417557],
#  [24.192019, -30.702276],
#  [-66.02673, -0.19714162],
#  [-76.30633, 23.294687],
#  [64.86323, -7.5324616],
#  [-46.06942, -48.18312],
#  [-65.93901, 34.91111],
#  [-88.496796, -10.843623],
#  [-53.98792, 18.414452],
#  [10.786277, 23.541183],
#  [-23.343966, -7.6279736],
#  [-68.22876, -8.215863],
#  [-63.429783, 5.405677],
#  [76.04629, 4.132905],
#  [-1.5599766, 75.64936],
#  [53.17151, -24.018698],
#  [-47.61871, -9.52223],
#  [-49.1544, 35.430283],
#  [-29.728092, 7.3792005],
#  [71.93502, -31.387127],
#  [-56.12171, -35.410885],
#  [30.318043, 31.809061],
#  [51.120583, -41.200333],
#  [10.845866, 23.577818],
#  [36.746067, -64.20414],
#  [-26.909782, -37.642387],
#  [56.361454, -19.085651],
#  [-5.5996246, -1.9994067],
#  [-7.5973444, 75.25461],
#  [19.496359, -39.797894],
#  [-61.13736, -29.899418],
#  [-56.981712, -34.33193],
#  [26.902224, 13.315191],
#  [-30.907322, -62.377274],
#  [-33.858784, -59.64072],
#  [-88.11643, -12.238501],
#  [-58.070175, 13.4012985],
#  [77.788345, -24.51431],
#  [-65.774124, -26.093267],
#  [53.84311, -41.136833],
#  [-85.63223, 8.504717],
#  [-63.82425, -27.584833],
#  [-63.538044, 36.931423],
#  [8.727062, -8.372307],
#  [32.00371, -69.13595],
#  [0.074335866, 23.129246],
#  [56.39139, -40.735527],
#  [87.99143, -5.448274],
#  [2.5472305, 6.2068596],
#  [30.484262, 31.472557],
#  [-87.88694, -12.958603],
#  [-88.26384, -11.721199],
#  [-84.05563, 11.686116],
#  [-45.320957, -48.958714],
#  [69.0092, -0.92203194],
#  [-21.710958, 25.708147],
#  [48.58096, -2.0268888],
#  [-49.212433, 26.707754],
#  [-1.1950498, -70.507805],
#  [-88.841606, -9.35333],
#  [-11.352217, 74.67354],
#  [49.540462, 6.3197823],
#  [88.17366, -9.387503],
#  [-78.19448, 20.813572],
#  [23.135841, 65.965385],
#  [-88.066635, 1.8507628],
#  [76.69149, 4.2172627],
#  [-36.217396, -57.385242],
#  [62.484314, -11.047443],
#  [-31.757095, -22.442858],
#  [2.2677715, 46.795734],
#  [33.950928, 58.260616],
#  [-42.61806, -51.535107],
#  [-43.05381, -51.135925],
#  [-84.35414, 11.12069],
#  [-52.838173, -39.720535],
#  [56.80829, -40.65954],
#  [20.10267, -40.39803],
#  [9.3666725, 24.796124],
#  [-53.15358, -39.307434],
#  [30.012362, 12.122296],
#  [-52.45367, 39.448227],
#  [-48.73887, 28.427353],
#  [-10.695301, -77.66368],
#  [-55.049797, -36.791283],
#  [-66.6063, -25.487497],
#  [34.385475, -66.7253],
#  [69.656876, -33.537838],
#  [-78.20239, 20.805141],
#  [-48.408756, 32.205215],
#  [-54.98559, 40.082386],
#  [-7.8293633, -41.949966],
#  [-79.71825, 18.694351],
#  [-84.49206, 10.854093],
#  [-0.2872322, 16.359615],
#  [-44.100037, -50.14102],
#  [-16.750618, 72.12446],
#  [0.25156435, 2.2115552],
#  [32.84206, 12.771444],
#  [-48.550484, 29.935862],
#  [2.5181067, 8.971429],
#  [-67.009445, -3.1392593],
#  [-17.47041, 11.841944],
#  [-69.395226, 31.417334],
#  [-2.0291312, -21.27169],
#  [-66.07175, -25.874983],
#  [77.493484, 4.2372613],
#  [18.266846, 68.13484],
#  [-66.08329, -0.35631198],
#  [-50.876842, 22.942886],
#  [24.842644, 34.37117],
#  [20.608631, 38.88284],
#  [76.91845, -25.64393],
#  [-11.483728, -78.23272],
#  [-20.559511, 70.16675],
#  [-49.954666, 36.935444],
#  [-6.657355, 74.766045],
#  [-65.19383, 35.56375],
#  [-40.699314, -53.295036],
#  [0.34685218, 23.37009],
#  [-62.92319, -28.30921],
#  [24.323082, 33.599483],
#  [19.886494, 67.75638],
#  [-45.311337, -48.966366],
#  [-28.834206, -35.985603],
#  [-3.5541646, 48.518345],
#  [-50.026558, 24.643745],
#  [87.29527, -3.0681605],
#  [-61.633423, 8.461422],
#  [-32.726086, -60.704815],
#  [-87.28865, 4.434279],
#  [-18.836035, -0.73743427],
#  [1.2503998, 14.364144],
#  [-33.969967, -59.530933],
#  [-49.74467, 25.311758],
#  [-66.89609, 34.00964],
#  [-23.40513, 29.759552],
#  [2.2840517, 74.4577],
#  [-49.49201, 36.16607],
#  [65.00974, -37.158962],
#  [79.73001, -21.87422],
#  [2.4387095, 11.415405],
#  [65.06155, -37.141945],
#  [-89.00287, -3.1382668],
#  [59.965214, -14.400578],
#  [31.314077, -69.810486],
#  [-14.346266, 13.804524],
#  [37.15187, -63.719646],
#  [-87.17786, -14.555676],
#  [8.2207365, 72.586365],
#  [55.98899, -40.78981],
#  [-51.788086, -41.136578],
#  [-4.3271284, -35.99123],
#  [25.85741, 13.682461],
#  [-85.73679, 8.271657],
#  [46.440544, 43.894028],
#  [-7.4794126, -45.70691],
#  [-60.93049, -30.099363],
#  [-30.493544, 7.4347024],
#  [-86.79505, -15.20292],
#  [-22.413628, -41.061855],
#  [-43.730118, -50.498047],
#  [-78.67411, 20.15561],
#  [-33.664097, -59.82503],
#  [4.169158, 73.92175],
#  [57.93151, -40.406853],
#  [-73.66311, 26.53592],
#  [8.761416, -59.234695],
#  [-43.34361, 5.7925687],
#  [-75.85912, 23.864307],
#  [-72.15984, 28.323465],
#  [-30.279247, 7.506976],
#  [-4.968959, -35.11622],
#  [0.30560154, -70.37764],
#  [-61.296337, -29.754957],
#  [-34.170326, 8.283206],
#  [-36.07359, 8.412568],
#  [27.76026, 62.22384],
#  [-16.54905, 12.946682],
#  [-16.478142, 8.386572],
#  [39.163155, 51.687294],
#  [48.428925, -2.5796196],
#  [-89.04033, -3.51774],
#  [-23.645996, 67.080605],
#  [-64.62386, 36.04774],
#  [2.6758263, 24.818832],
#  [-24.928616, -13.84103],
#  [-55.00326, 40.080704],
#  [7.5674357, 25.644663],
#  [-19.459276, -7.353921],
#  [83.94056, 1.7595851],
#  [-58.470936, -32.60901],
#  [0.95633376, 13.245741],
#  [-30.796312, -30.211266],
#  [88.1918, -6.9041705],
#  [-54.611076, -37.364647],
#  [-87.27726, -14.369474],
#  [18.20468, 69.32134],
#  [-3.4994977, -32.573723],
#  [-7.3970666, 75.2159],
#  [-43.561802, -50.655487],
#  [-31.557854, -23.961712],
#  [-51.617348, -41.360664],
#  [0.32875285, 1.9928937],
#  [-68.87867, -12.549551],
#  [-30.871475, -62.41059],
#  [-65.921104, 0.0645648],
#  [0.2851198, 15.902683],
#  [-82.06633, 15.161532],
#  [-32.066063, -61.30784],
#  [-14.698546, 72.52612],
#  [11.668679, -5.0778913],
#  [2.0303926, 74.62373],
#  [-58.3698, -32.722706],
#  [50.379574, 0.4851053],
#  [-62.606834, -28.573986],
#  [83.45609, 2.1616452],
#  [24.414186, 64.96615],
#  [42.47689, -40.16626],
#  [-65.8882, 34.955692],
#  [37.49443, -63.289692],
#  [30.284662, -70.78484],
#  [-35.986374, 9.4471035],
#  [-52.075768, -40.74713],
#  [22.232399, 65.86187],
#  [37.1902, -63.673058],
#  [-56.708153, 15.09874],
#  [-64.833, 2.5698116],
#  [2.2394624, 12.655776],
#  [10.988394, -5.884379],
#  [28.288055, 12.724238],
#  [-18.461567, 15.576053],
#  [30.44568, -21.141207],
#  [41.803505, -56.071976],
#  [-0.7047409, 16.43806],
#  [-47.99182, -46.00702],
#  [57.9578, -40.396454],
#  [-6.1887474, -41.86479],
#  [-58.13954, -32.982697],
#  [-50.555008, -42.78207],
#  [-80.93808, 16.897362],
#  [-48.27091, -45.677],
#  [-21.759293, 67.44755],
#  [27.114513, 63.455982],
#  [-0.60112596, -23.540428],
#  [-80.18084, 18.027554],
#  [-36.02369, -57.567394],
#  [25.608152, -6.3019505],
#  [-31.621916, -22.764946],
#  [20.928942, 68.06571],
#  [-9.5580635, -46.975773],
#  [28.346045, -15.370247],
#  [-3.3534524, -0.93642336],
#  [29.957144, 30.704514],
#  [9.550634, 23.997004],
#  [6.782228, 24.9679],
#  [-89.10625, -4.4057145],
#  [-23.108675, 38.396423],
#  [34.81544, 58.447853],
#  [66.54532, -4.8033657],
#  [-70.53543, 30.163216],
#  [62.983196, -38.312786],
#  [-61.465775, 8.73173],
#  [75.40852, 4.0068235],
#  [-16.43512, -47.00374],
#  [56.752045, -40.66003],
#  [43.18855, 11.445247],
#  [-33.155243, -60.304825],
#  [2.1231415, -14.602986],
#  [-17.00293, -44.9071],
#  [-63.46182, 5.349147],
#  [-88.60187, -0.5069984],
#  [-61.16778, 9.177356],
#  [35.74484, 56.677246],
#  [47.611874, -2.2657297],
#  [76.67313, -25.948175],
#  [35.06815, 56.37388],
#  [-68.40388, -9.185981],
#  [2.4736228, 49.21715],
#  [-16.091549, 10.697699],
#  [42.556873, 30.440762],
#  [-4.1510396, -38.905254],
#  [-84.74925, 10.339669],
#  [25.1563, 35.43241],
#  [-53.92123, -38.27599],
#  [10.750335, 73.16499],
#  [-36.897503, 8.73816],
#  [-54.380795, 17.92125],
#  [9.496916, 45.883816],
#  [13.844058, 21.16835],
#  [28.541557, -72.32252],
#  [42.222904, -55.195618],
#  [-9.199179, 46.9929],
#  [-54.78946, -37.130894],
#  [61.227123, -39.1906],
#  [-1.9331921, -34.723324],
#  [65.167816, -7.0573874],
#  [-89.06744, -7.744868],
#  [12.3401165, -7.563515],
#  [-84.89382, 10.052495],
#  [47.565083, -40.68012],
#  [-86.44762, 6.635045],
#  ...]

# %%
from sklearn.cluster import SpectralClustering
clustering = SpectralClustering().fit(X)
groups = clustering.labels_
plt.figure(figsize=(8,8))
sns.scatterplot(x=x_vals,y=y_vals,hue=groups,palette='deep',legend='full')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-f7a358197c95> in <module>
#       1 from sklearn.cluster import SpectralClustering
# ----> 2 clustering = SpectralClustering().fit(X)
#       3 groups = clustering.labels_
#       4 plt.figure(figsize=(8,8))
#       5 sns.scatterplot(x=x_vals,y=y_vals,hue=groups,palette='deep',legend='full')
#
# ~\anaconda3\envs\word2vec\lib\site-packages\sklearn\cluster\_spectral.py in fit(self, X, y)
#     533
#     534         random_state = check_random_state(self.random_state)
# --> 535         self.labels_ = spectral_clustering(self.affinity_matrix_,
#     536                                            n_clusters=self.n_clusters,
#     537                                            n_components=self.n_components,
#
# ~\anaconda3\envs\word2vec\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\word2vec\lib\site-packages\sklearn\cluster\_spectral.py in spectral_clustering(affinity, n_clusters, n_components, eigen_solver, random_state, n_init, eigen_tol, assign_labels, verbose)
#     269     # and should be kept for spectral clustering (drop_first = False)
#     270     # See spectral_embedding documentation.
# --> 271     maps = spectral_embedding(affinity, n_components=n_components,
#     272                               eigen_solver=eigen_solver,
#     273                               random_state=random_state,
#
# ~\anaconda3\envs\word2vec\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\word2vec\lib\site-packages\sklearn\manifold\_spectral_embedding.py in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     219       https://doi.org/10.1137%2FS1064827500366124
#     220     """
# --> 221     adjacency = check_symmetric(adjacency)
#     222
#     223     try:
#
# ~\anaconda3\envs\word2vec\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\word2vec\lib\site-packages\sklearn\utils\validation.py in check_symmetric(array, tol, raise_warning, raise_exception)
#     957         symmetric = np.all(abs(diff.data) < tol)
#     958     else:
# --> 959         symmetric = np.allclose(array, array.T, atol=tol)
#     960
#     961     if not symmetric:
#
# <__array_function__ internals> in allclose(*args, **kwargs)
#
# ~\anaconda3\envs\word2vec\lib\site-packages\numpy\core\numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2254
#    2255     """
# -> 2256     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2257     return bool(res)
#    2258
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# ~\anaconda3\envs\word2vec\lib\site-packages\numpy\core\numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2363     yfin = isfinite(y)
#    2364     if all(xfin) and all(yfin):
# -> 2365         return within_tol(x, y, atol, rtol)
#    2366     else:
#    2367         finite = xfin & yfin
#
# ~\anaconda3\envs\word2vec\lib\site-packages\numpy\core\numeric.py in within_tol(x, y, atol, rtol)
#    2344     def within_tol(x, y, atol, rtol):
#    2345         with errstate(invalid='ignore'):
# -> 2346             return less_equal(abs(x-y), atol + rtol * abs(y))
#    2347
#    2348     x = asanyarray(a)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=x_vals,y=y_vals,hue=groups,palette='deep',legend='full')
plt.legend()

# %%
words = ['house_republicans','democrat','biden']
for word in words:
    result = model.wv.most_similar(word)
    print(result)
# Out:
# [('u', 0.9998445510864258), ('women', 0.999843955039978), ('children', 0.999843955039978), ('public', 0.9998438954353333), ('could', 0.9998437762260437), ('group', 0.9998437166213989), ('school', 0.9998435974121094), ('without', 0.9998434782028198), ('schools', 0.9998434782028198), ('trump', 0.9998432397842407)]
# [('said', 0.9999943971633911), ('also', 0.9999940395355225), ('two', 0.9999938607215881), ('state', 0.9999938011169434), ('would', 0.9999938011169434), ('could', 0.9999938011169434), ('one', 0.9999936819076538), ('including', 0.9999936819076538), ('u', 0.9999935030937195), ('made', 0.9999935030937195)]
# [('said', 0.9999958872795105), ('would', 0.9999956488609314), ('also', 0.9999954104423523), ('one', 0.9999953508377075), ('two', 0.9999953508377075), ('u', 0.9999952912330627), ('first', 0.9999951124191284), ('made', 0.9999951124191284), ('could', 0.9999950528144836), ('china', 0.9999950528144836)]
